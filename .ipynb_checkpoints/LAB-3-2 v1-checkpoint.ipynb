# %%
# %matplotlib inline

# %% [markdown]
# Transfer Learning Tutorial
# ==========================
# **Author**: `Sasank Chilamkurthy <https://chsasank.github.io>`_
#
# In this tutorial, you will learn how to train your network using
# transfer learning. You can read more about the transfer learning at `cs231n
# notes <http://cs231n.github.io/transfer-learning/>`__
#
# Quoting these notes,
#
#     In practice, very few people train an entire Convolutional Network
#     from scratch (with random initialization), because it is relatively
#     rare to have a dataset of sufficient size. Instead, it is common to
#     pretrain a ConvNet on a very large dataset (e.g. ImageNet, which
#     contains 1.2 million images with 1000 categories), and then use the
#     ConvNet either as an initialization or a fixed feature extractor for
#     the task of interest.
#
# These two major transfer learning scenarios look as follows:
#
# -  **Finetuning the convnet**: Instead of random initializaion, we
#    initialize the network with a pretrained network, like the one that is
#    trained on imagenet 1000 dataset. Rest of the training looks as
#    usual.
# -  **ConvNet as fixed feature extractor**: Here, we will freeze the weights
#    for all of the network except that of the final fully connected
#    layer. This last fully connected layer is replaced with a new one
#    with random weights and only this layer is trained.

# %%
# License: BSD
# Author: Sasank Chilamkurthy

from __future__ import print_function, division

import torch
import torch.nn as nn
import torch.optim as optim
from torch.optim import lr_scheduler
import numpy as np
import torchvision
from torchvision import datasets, models, transforms
import matplotlib.pyplot as plt
import time
import os
import copy

plt.ion()   # interactive mode

# %%
filepath = 'sample11@100.dms'  
with open(filepath) as fp:  
   line = fp.readline()
   cnt = 1
   while line:
       print("cp ../data/src_food/training/{} ../data/food-training-sample".format(line.strip()))
       line = fp.readline()
       cnt += 1
# Out:
# cp ../data/src_food/training/0_0.jpg ../data/food-training-sample
# cp ../data/src_food/training/0_116.jpg ../data/food-training-sample
# cp ../data/src_food/training/0_122.jpg ../data/food-training-sample
# cp ../data/src_food/training/0_123.jpg ../data/food-training-sample
# cp ../data/src_food/training/0_125.jpg ../data/food-training-sample
# cp ../data/src_food/training/0_130.jpg ../data/food-training-sample
# cp ../data/src_food/training/0_136.jpg ../data/food-training-sample
# cp ../data/src_food/training/0_14.jpg ../data/food-training-sample
# cp ../data/src_food/training/0_150.jpg ../data/food-training-sample
# cp ../data/src_food/training/0_161.jpg ../data/food-training-sample
# cp ../data/src_food/training/0_170.jpg ../data/food-training-sample
# cp ../data/src_food/training/0_202.jpg ../data/food-training-sample
# cp ../data/src_food/training/0_210.jpg ../data/food-training-sample
# cp ../data/src_food/training/0_212.jpg ../data/food-training-sample
# cp ../data/src_food/training/0_213.jpg ../data/food-training-sample
# cp ../data/src_food/training/0_220.jpg ../data/food-training-sample
# cp ../data/src_food/training/0_221.jpg ../data/food-training-sample
# cp ../data/src_food/training/0_234.jpg ../data/food-training-sample
# cp ../data/src_food/training/0_265.jpg ../data/food-training-sample
# cp ../data/src_food/training/0_266.jpg ../data/food-training-sample
# cp ../data/src_food/training/0_271.jpg ../data/food-training-sample
# cp ../data/src_food/training/0_274.jpg ../data/food-training-sample
# cp ../data/src_food/training/0_281.jpg ../data/food-training-sample
# cp ../data/src_food/training/0_28.jpg ../data/food-training-sample
# cp ../data/src_food/training/0_299.jpg ../data/food-training-sample
# cp ../data/src_food/training/0_304.jpg ../data/food-training-sample
# cp ../data/src_food/training/0_309.jpg ../data/food-training-sample
# cp ../data/src_food/training/0_315.jpg ../data/food-training-sample
# cp ../data/src_food/training/0_352.jpg ../data/food-training-sample
# cp ../data/src_food/training/0_357.jpg ../data/food-training-sample
# cp ../data/src_food/training/0_374.jpg ../data/food-training-sample
# cp ../data/src_food/training/0_379.jpg ../data/food-training-sample
# cp ../data/src_food/training/0_386.jpg ../data/food-training-sample
# cp ../data/src_food/training/0_392.jpg ../data/food-training-sample
# cp ../data/src_food/training/0_394.jpg ../data/food-training-sample
# cp ../data/src_food/training/0_3.jpg ../data/food-training-sample
# cp ../data/src_food/training/0_408.jpg ../data/food-training-sample
# cp ../data/src_food/training/0_411.jpg ../data/food-training-sample
# cp ../data/src_food/training/0_414.jpg ../data/food-training-sample
# cp ../data/src_food/training/0_416.jpg ../data/food-training-sample
# cp ../data/src_food/training/0_423.jpg ../data/food-training-sample
# cp ../data/src_food/training/0_437.jpg ../data/food-training-sample
# cp ../data/src_food/training/0_450.jpg ../data/food-training-sample
# cp ../data/src_food/training/0_468.jpg ../data/food-training-sample
# cp ../data/src_food/training/0_47.jpg ../data/food-training-sample
# cp ../data/src_food/training/0_484.jpg ../data/food-training-sample
# cp ../data/src_food/training/0_48.jpg ../data/food-training-sample
# cp ../data/src_food/training/0_496.jpg ../data/food-training-sample
# cp ../data/src_food/training/0_504.jpg ../data/food-training-sample
# cp ../data/src_food/training/0_513.jpg ../data/food-training-sample
# cp ../data/src_food/training/0_514.jpg ../data/food-training-sample
# cp ../data/src_food/training/0_518.jpg ../data/food-training-sample
# cp ../data/src_food/training/0_526.jpg ../data/food-training-sample
# cp ../data/src_food/training/0_528.jpg ../data/food-training-sample
# cp ../data/src_food/training/0_548.jpg ../data/food-training-sample
# cp ../data/src_food/training/0_579.jpg ../data/food-training-sample
# cp ../data/src_food/training/0_588.jpg ../data/food-training-sample
# cp ../data/src_food/training/0_591.jpg ../data/food-training-sample
# cp ../data/src_food/training/0_596.jpg ../data/food-training-sample
# cp ../data/src_food/training/0_599.jpg ../data/food-training-sample
# cp ../data/src_food/training/0_601.jpg ../data/food-training-sample
# cp ../data/src_food/training/0_602.jpg ../data/food-training-sample
# cp ../data/src_food/training/0_604.jpg ../data/food-training-sample
# cp ../data/src_food/training/0_60.jpg ../data/food-training-sample
# cp ../data/src_food/training/0_621.jpg ../data/food-training-sample
# cp ../data/src_food/training/0_626.jpg ../data/food-training-sample
# cp ../data/src_food/training/0_627.jpg ../data/food-training-sample
# cp ../data/src_food/training/0_650.jpg ../data/food-training-sample
# cp ../data/src_food/training/0_656.jpg ../data/food-training-sample
# cp ../data/src_food/training/0_668.jpg ../data/food-training-sample
# cp ../data/src_food/training/0_673.jpg ../data/food-training-sample
# cp ../data/src_food/training/0_689.jpg ../data/food-training-sample
# cp ../data/src_food/training/0_690.jpg ../data/food-training-sample
# cp ../data/src_food/training/0_695.jpg ../data/food-training-sample
# cp ../data/src_food/training/0_697.jpg ../data/food-training-sample
# cp ../data/src_food/training/0_709.jpg ../data/food-training-sample
# cp ../data/src_food/training/0_714.jpg ../data/food-training-sample
# cp ../data/src_food/training/0_733.jpg ../data/food-training-sample
# cp ../data/src_food/training/0_744.jpg ../data/food-training-sample
# cp ../data/src_food/training/0_757.jpg ../data/food-training-sample
# cp ../data/src_food/training/0_758.jpg ../data/food-training-sample
# cp ../data/src_food/training/0_762.jpg ../data/food-training-sample
# cp ../data/src_food/training/0_777.jpg ../data/food-training-sample
# cp ../data/src_food/training/0_783.jpg ../data/food-training-sample
# cp ../data/src_food/training/0_784.jpg ../data/food-training-sample
# cp ../data/src_food/training/0_808.jpg ../data/food-training-sample
# cp ../data/src_food/training/0_815.jpg ../data/food-training-sample
# cp ../data/src_food/training/0_828.jpg ../data/food-training-sample
# cp ../data/src_food/training/0_846.jpg ../data/food-training-sample
# cp ../data/src_food/training/0_863.jpg ../data/food-training-sample
# cp ../data/src_food/training/0_87.jpg ../data/food-training-sample
# cp ../data/src_food/training/0_897.jpg ../data/food-training-sample
# cp ../data/src_food/training/0_8.jpg ../data/food-training-sample
# cp ../data/src_food/training/0_911.jpg ../data/food-training-sample
# cp ../data/src_food/training/0_951.jpg ../data/food-training-sample
# cp ../data/src_food/training/0_962.jpg ../data/food-training-sample
# cp ../data/src_food/training/0_967.jpg ../data/food-training-sample
# cp ../data/src_food/training/0_970.jpg ../data/food-training-sample
# cp ../data/src_food/training/0_97.jpg ../data/food-training-sample
# cp ../data/src_food/training/0_981.jpg ../data/food-training-sample
# cp ../data/src_food/training/1_0.jpg ../data/food-training-sample
# cp ../data/src_food/training/1_102.jpg ../data/food-training-sample
# cp ../data/src_food/training/1_103.jpg ../data/food-training-sample
# cp ../data/src_food/training/1_104.jpg ../data/food-training-sample
# cp ../data/src_food/training/1_105.jpg ../data/food-training-sample
# cp ../data/src_food/training/1_108.jpg ../data/food-training-sample
# cp ../data/src_food/training/1_10.jpg ../data/food-training-sample
# cp ../data/src_food/training/1_119.jpg ../data/food-training-sample
# cp ../data/src_food/training/1_11.jpg ../data/food-training-sample
# cp ../data/src_food/training/1_122.jpg ../data/food-training-sample
# cp ../data/src_food/training/1_12.jpg ../data/food-training-sample
# cp ../data/src_food/training/1_131.jpg ../data/food-training-sample
# cp ../data/src_food/training/1_138.jpg ../data/food-training-sample
# cp ../data/src_food/training/1_13.jpg ../data/food-training-sample
# cp ../data/src_food/training/1_14.jpg ../data/food-training-sample
# cp ../data/src_food/training/1_150.jpg ../data/food-training-sample
# cp ../data/src_food/training/1_153.jpg ../data/food-training-sample
# cp ../data/src_food/training/1_158.jpg ../data/food-training-sample
# cp ../data/src_food/training/1_161.jpg ../data/food-training-sample
# cp ../data/src_food/training/1_172.jpg ../data/food-training-sample
# cp ../data/src_food/training/1_174.jpg ../data/food-training-sample
# cp ../data/src_food/training/1_175.jpg ../data/food-training-sample
# cp ../data/src_food/training/1_180.jpg ../data/food-training-sample
# cp ../data/src_food/training/1_181.jpg ../data/food-training-sample
# cp ../data/src_food/training/1_186.jpg ../data/food-training-sample
# cp ../data/src_food/training/1_189.jpg ../data/food-training-sample
# cp ../data/src_food/training/1_190.jpg ../data/food-training-sample
# cp ../data/src_food/training/1_195.jpg ../data/food-training-sample
# cp ../data/src_food/training/1_1.jpg ../data/food-training-sample
# cp ../data/src_food/training/1_201.jpg ../data/food-training-sample
# cp ../data/src_food/training/1_204.jpg ../data/food-training-sample
# cp ../data/src_food/training/1_205.jpg ../data/food-training-sample
# cp ../data/src_food/training/1_211.jpg ../data/food-training-sample
# cp ../data/src_food/training/1_220.jpg ../data/food-training-sample
# cp ../data/src_food/training/1_225.jpg ../data/food-training-sample
# cp ../data/src_food/training/1_235.jpg ../data/food-training-sample
# cp ../data/src_food/training/1_237.jpg ../data/food-training-sample
# cp ../data/src_food/training/1_245.jpg ../data/food-training-sample
# cp ../data/src_food/training/1_250.jpg ../data/food-training-sample
# cp ../data/src_food/training/1_258.jpg ../data/food-training-sample
# cp ../data/src_food/training/1_261.jpg ../data/food-training-sample
# cp ../data/src_food/training/1_264.jpg ../data/food-training-sample
# cp ../data/src_food/training/1_267.jpg ../data/food-training-sample
# cp ../data/src_food/training/1_268.jpg ../data/food-training-sample
# cp ../data/src_food/training/1_277.jpg ../data/food-training-sample
# cp ../data/src_food/training/1_285.jpg ../data/food-training-sample
# cp ../data/src_food/training/1_287.jpg ../data/food-training-sample
# cp ../data/src_food/training/1_289.jpg ../data/food-training-sample
# cp ../data/src_food/training/1_290.jpg ../data/food-training-sample
# cp ../data/src_food/training/1_297.jpg ../data/food-training-sample
# cp ../data/src_food/training/1_29.jpg ../data/food-training-sample
# cp ../data/src_food/training/1_304.jpg ../data/food-training-sample
# cp ../data/src_food/training/1_307.jpg ../data/food-training-sample
# cp ../data/src_food/training/1_30.jpg ../data/food-training-sample
# cp ../data/src_food/training/1_310.jpg ../data/food-training-sample
# cp ../data/src_food/training/1_311.jpg ../data/food-training-sample
# cp ../data/src_food/training/1_314.jpg ../data/food-training-sample
# cp ../data/src_food/training/1_324.jpg ../data/food-training-sample
# cp ../data/src_food/training/1_327.jpg ../data/food-training-sample
# cp ../data/src_food/training/1_332.jpg ../data/food-training-sample
# cp ../data/src_food/training/1_339.jpg ../data/food-training-sample
# cp ../data/src_food/training/1_33.jpg ../data/food-training-sample
# cp ../data/src_food/training/1_340.jpg ../data/food-training-sample
# cp ../data/src_food/training/1_344.jpg ../data/food-training-sample
# cp ../data/src_food/training/1_351.jpg ../data/food-training-sample
# cp ../data/src_food/training/1_352.jpg ../data/food-training-sample
# cp ../data/src_food/training/1_357.jpg ../data/food-training-sample
# cp ../data/src_food/training/1_377.jpg ../data/food-training-sample
# cp ../data/src_food/training/1_385.jpg ../data/food-training-sample
# cp ../data/src_food/training/1_38.jpg ../data/food-training-sample
# cp ../data/src_food/training/1_391.jpg ../data/food-training-sample
# cp ../data/src_food/training/1_395.jpg ../data/food-training-sample
# cp ../data/src_food/training/1_401.jpg ../data/food-training-sample
# cp ../data/src_food/training/1_402.jpg ../data/food-training-sample
# cp ../data/src_food/training/1_403.jpg ../data/food-training-sample
# cp ../data/src_food/training/1_404.jpg ../data/food-training-sample
# cp ../data/src_food/training/1_405.jpg ../data/food-training-sample
# cp ../data/src_food/training/1_406.jpg ../data/food-training-sample
# cp ../data/src_food/training/1_407.jpg ../data/food-training-sample
# cp ../data/src_food/training/1_421.jpg ../data/food-training-sample
# cp ../data/src_food/training/1_423.jpg ../data/food-training-sample
# cp ../data/src_food/training/1_424.jpg ../data/food-training-sample
# cp ../data/src_food/training/1_42.jpg ../data/food-training-sample
# cp ../data/src_food/training/1_46.jpg ../data/food-training-sample
# cp ../data/src_food/training/1_49.jpg ../data/food-training-sample
# cp ../data/src_food/training/1_52.jpg ../data/food-training-sample
# cp ../data/src_food/training/1_53.jpg ../data/food-training-sample
# cp ../data/src_food/training/1_58.jpg ../data/food-training-sample
# cp ../data/src_food/training/1_5.jpg ../data/food-training-sample
# cp ../data/src_food/training/1_70.jpg ../data/food-training-sample
# cp ../data/src_food/training/1_72.jpg ../data/food-training-sample
# cp ../data/src_food/training/1_73.jpg ../data/food-training-sample
# cp ../data/src_food/training/1_75.jpg ../data/food-training-sample
# cp ../data/src_food/training/1_85.jpg ../data/food-training-sample
# cp ../data/src_food/training/1_86.jpg ../data/food-training-sample
# cp ../data/src_food/training/1_88.jpg ../data/food-training-sample
# cp ../data/src_food/training/1_90.jpg ../data/food-training-sample
# cp ../data/src_food/training/1_92.jpg ../data/food-training-sample
# cp ../data/src_food/training/1_95.jpg ../data/food-training-sample
# cp ../data/src_food/training/1_99.jpg ../data/food-training-sample
# cp ../data/src_food/training/2_1001.jpg ../data/food-training-sample
# cp ../data/src_food/training/2_1021.jpg ../data/food-training-sample
# cp ../data/src_food/training/2_1027.jpg ../data/food-training-sample
# cp ../data/src_food/training/2_103.jpg ../data/food-training-sample
# cp ../data/src_food/training/2_1048.jpg ../data/food-training-sample
# cp ../data/src_food/training/2_1059.jpg ../data/food-training-sample
# cp ../data/src_food/training/2_1062.jpg ../data/food-training-sample
# cp ../data/src_food/training/2_1078.jpg ../data/food-training-sample
# cp ../data/src_food/training/2_1094.jpg ../data/food-training-sample
# cp ../data/src_food/training/2_1100.jpg ../data/food-training-sample
# cp ../data/src_food/training/2_1102.jpg ../data/food-training-sample
# cp ../data/src_food/training/2_110.jpg ../data/food-training-sample
# cp ../data/src_food/training/2_1138.jpg ../data/food-training-sample
# cp ../data/src_food/training/2_1176.jpg ../data/food-training-sample
# cp ../data/src_food/training/2_118.jpg ../data/food-training-sample
# cp ../data/src_food/training/2_1195.jpg ../data/food-training-sample
# cp ../data/src_food/training/2_1198.jpg ../data/food-training-sample
# cp ../data/src_food/training/2_1223.jpg ../data/food-training-sample
# cp ../data/src_food/training/2_1245.jpg ../data/food-training-sample
# cp ../data/src_food/training/2_124.jpg ../data/food-training-sample
# cp ../data/src_food/training/2_1264.jpg ../data/food-training-sample
# cp ../data/src_food/training/2_1270.jpg ../data/food-training-sample
# cp ../data/src_food/training/2_1285.jpg ../data/food-training-sample
# cp ../data/src_food/training/2_1292.jpg ../data/food-training-sample
# cp ../data/src_food/training/2_1302.jpg ../data/food-training-sample
# cp ../data/src_food/training/2_1307.jpg ../data/food-training-sample
# cp ../data/src_food/training/2_1342.jpg ../data/food-training-sample
# cp ../data/src_food/training/2_1365.jpg ../data/food-training-sample
# cp ../data/src_food/training/2_137.jpg ../data/food-training-sample
# cp ../data/src_food/training/2_1419.jpg ../data/food-training-sample
# cp ../data/src_food/training/2_1433.jpg ../data/food-training-sample
# cp ../data/src_food/training/2_1434.jpg ../data/food-training-sample
# cp ../data/src_food/training/2_143.jpg ../data/food-training-sample
# cp ../data/src_food/training/2_1448.jpg ../data/food-training-sample
# cp ../data/src_food/training/2_1449.jpg ../data/food-training-sample
# cp ../data/src_food/training/2_1458.jpg ../data/food-training-sample
# cp ../data/src_food/training/2_1493.jpg ../data/food-training-sample
# cp ../data/src_food/training/2_149.jpg ../data/food-training-sample
# cp ../data/src_food/training/2_165.jpg ../data/food-training-sample
# cp ../data/src_food/training/2_178.jpg ../data/food-training-sample
# cp ../data/src_food/training/2_197.jpg ../data/food-training-sample
# cp ../data/src_food/training/2_202.jpg ../data/food-training-sample
# cp ../data/src_food/training/2_211.jpg ../data/food-training-sample
# cp ../data/src_food/training/2_220.jpg ../data/food-training-sample
# cp ../data/src_food/training/2_226.jpg ../data/food-training-sample
# cp ../data/src_food/training/2_234.jpg ../data/food-training-sample
# cp ../data/src_food/training/2_240.jpg ../data/food-training-sample
# cp ../data/src_food/training/2_268.jpg ../data/food-training-sample
# cp ../data/src_food/training/2_285.jpg ../data/food-training-sample
# cp ../data/src_food/training/2_287.jpg ../data/food-training-sample
# cp ../data/src_food/training/2_334.jpg ../data/food-training-sample
# cp ../data/src_food/training/2_341.jpg ../data/food-training-sample
# cp ../data/src_food/training/2_359.jpg ../data/food-training-sample
# cp ../data/src_food/training/2_396.jpg ../data/food-training-sample
# cp ../data/src_food/training/2_448.jpg ../data/food-training-sample
# cp ../data/src_food/training/2_451.jpg ../data/food-training-sample
# cp ../data/src_food/training/2_453.jpg ../data/food-training-sample
# cp ../data/src_food/training/2_490.jpg ../data/food-training-sample
# cp ../data/src_food/training/2_525.jpg ../data/food-training-sample
# cp ../data/src_food/training/2_528.jpg ../data/food-training-sample
# cp ../data/src_food/training/2_546.jpg ../data/food-training-sample
# cp ../data/src_food/training/2_586.jpg ../data/food-training-sample
# cp ../data/src_food/training/2_601.jpg ../data/food-training-sample
# cp ../data/src_food/training/2_609.jpg ../data/food-training-sample
# cp ../data/src_food/training/2_61.jpg ../data/food-training-sample
# cp ../data/src_food/training/2_642.jpg ../data/food-training-sample
# cp ../data/src_food/training/2_651.jpg ../data/food-training-sample
# cp ../data/src_food/training/2_653.jpg ../data/food-training-sample
# cp ../data/src_food/training/2_659.jpg ../data/food-training-sample
# cp ../data/src_food/training/2_662.jpg ../data/food-training-sample
# cp ../data/src_food/training/2_672.jpg ../data/food-training-sample
# cp ../data/src_food/training/2_673.jpg ../data/food-training-sample
# cp ../data/src_food/training/2_697.jpg ../data/food-training-sample
# cp ../data/src_food/training/2_727.jpg ../data/food-training-sample
# cp ../data/src_food/training/2_735.jpg ../data/food-training-sample
# cp ../data/src_food/training/2_73.jpg ../data/food-training-sample
# cp ../data/src_food/training/2_741.jpg ../data/food-training-sample
# cp ../data/src_food/training/2_745.jpg ../data/food-training-sample
# cp ../data/src_food/training/2_746.jpg ../data/food-training-sample
# cp ../data/src_food/training/2_749.jpg ../data/food-training-sample
# cp ../data/src_food/training/2_756.jpg ../data/food-training-sample
# cp ../data/src_food/training/2_76.jpg ../data/food-training-sample
# cp ../data/src_food/training/2_778.jpg ../data/food-training-sample
# cp ../data/src_food/training/2_786.jpg ../data/food-training-sample
# cp ../data/src_food/training/2_787.jpg ../data/food-training-sample
# cp ../data/src_food/training/2_78.jpg ../data/food-training-sample
# cp ../data/src_food/training/2_801.jpg ../data/food-training-sample
# cp ../data/src_food/training/2_802.jpg ../data/food-training-sample
# cp ../data/src_food/training/2_811.jpg ../data/food-training-sample
# cp ../data/src_food/training/2_81.jpg ../data/food-training-sample
# cp ../data/src_food/training/2_827.jpg ../data/food-training-sample
# cp ../data/src_food/training/2_841.jpg ../data/food-training-sample
# cp ../data/src_food/training/2_872.jpg ../data/food-training-sample
# cp ../data/src_food/training/2_882.jpg ../data/food-training-sample
# cp ../data/src_food/training/2_887.jpg ../data/food-training-sample
# cp ../data/src_food/training/2_906.jpg ../data/food-training-sample
# cp ../data/src_food/training/2_91.jpg ../data/food-training-sample
# cp ../data/src_food/training/2_926.jpg ../data/food-training-sample
# cp ../data/src_food/training/2_93.jpg ../data/food-training-sample
# cp ../data/src_food/training/2_949.jpg ../data/food-training-sample
# cp ../data/src_food/training/3_101.jpg ../data/food-training-sample
# cp ../data/src_food/training/3_106.jpg ../data/food-training-sample
# cp ../data/src_food/training/3_109.jpg ../data/food-training-sample
# cp ../data/src_food/training/3_111.jpg ../data/food-training-sample
# cp ../data/src_food/training/3_116.jpg ../data/food-training-sample
# cp ../data/src_food/training/3_117.jpg ../data/food-training-sample
# cp ../data/src_food/training/3_126.jpg ../data/food-training-sample
# cp ../data/src_food/training/3_127.jpg ../data/food-training-sample
# cp ../data/src_food/training/3_129.jpg ../data/food-training-sample
# cp ../data/src_food/training/3_137.jpg ../data/food-training-sample
# cp ../data/src_food/training/3_139.jpg ../data/food-training-sample
# cp ../data/src_food/training/3_157.jpg ../data/food-training-sample
# cp ../data/src_food/training/3_159.jpg ../data/food-training-sample
# cp ../data/src_food/training/3_164.jpg ../data/food-training-sample
# cp ../data/src_food/training/3_182.jpg ../data/food-training-sample
# cp ../data/src_food/training/3_189.jpg ../data/food-training-sample
# cp ../data/src_food/training/3_192.jpg ../data/food-training-sample
# cp ../data/src_food/training/3_213.jpg ../data/food-training-sample
# cp ../data/src_food/training/3_218.jpg ../data/food-training-sample
# cp ../data/src_food/training/3_21.jpg ../data/food-training-sample
# cp ../data/src_food/training/3_228.jpg ../data/food-training-sample
# cp ../data/src_food/training/3_229.jpg ../data/food-training-sample
# cp ../data/src_food/training/3_22.jpg ../data/food-training-sample
# cp ../data/src_food/training/3_244.jpg ../data/food-training-sample
# cp ../data/src_food/training/3_249.jpg ../data/food-training-sample
# cp ../data/src_food/training/3_290.jpg ../data/food-training-sample
# cp ../data/src_food/training/3_295.jpg ../data/food-training-sample
# cp ../data/src_food/training/3_298.jpg ../data/food-training-sample
# cp ../data/src_food/training/3_302.jpg ../data/food-training-sample
# cp ../data/src_food/training/3_317.jpg ../data/food-training-sample
# cp ../data/src_food/training/3_330.jpg ../data/food-training-sample
# cp ../data/src_food/training/3_340.jpg ../data/food-training-sample
# cp ../data/src_food/training/3_342.jpg ../data/food-training-sample
# cp ../data/src_food/training/3_344.jpg ../data/food-training-sample
# cp ../data/src_food/training/3_348.jpg ../data/food-training-sample
# cp ../data/src_food/training/3_359.jpg ../data/food-training-sample
# cp ../data/src_food/training/3_362.jpg ../data/food-training-sample
# cp ../data/src_food/training/3_377.jpg ../data/food-training-sample
# cp ../data/src_food/training/3_385.jpg ../data/food-training-sample
# cp ../data/src_food/training/3_38.jpg ../data/food-training-sample
# cp ../data/src_food/training/3_390.jpg ../data/food-training-sample
# cp ../data/src_food/training/3_392.jpg ../data/food-training-sample
# cp ../data/src_food/training/3_396.jpg ../data/food-training-sample
# cp ../data/src_food/training/3_407.jpg ../data/food-training-sample
# cp ../data/src_food/training/3_411.jpg ../data/food-training-sample
# cp ../data/src_food/training/3_415.jpg ../data/food-training-sample
# cp ../data/src_food/training/3_434.jpg ../data/food-training-sample
# cp ../data/src_food/training/3_447.jpg ../data/food-training-sample
# cp ../data/src_food/training/3_448.jpg ../data/food-training-sample
# cp ../data/src_food/training/3_459.jpg ../data/food-training-sample
# cp ../data/src_food/training/3_460.jpg ../data/food-training-sample
# cp ../data/src_food/training/3_465.jpg ../data/food-training-sample
# cp ../data/src_food/training/3_476.jpg ../data/food-training-sample
# cp ../data/src_food/training/3_480.jpg ../data/food-training-sample
# cp ../data/src_food/training/3_497.jpg ../data/food-training-sample
# cp ../data/src_food/training/3_500.jpg ../data/food-training-sample
# cp ../data/src_food/training/3_50.jpg ../data/food-training-sample
# cp ../data/src_food/training/3_518.jpg ../data/food-training-sample
# cp ../data/src_food/training/3_525.jpg ../data/food-training-sample
# cp ../data/src_food/training/3_526.jpg ../data/food-training-sample
# cp ../data/src_food/training/3_539.jpg ../data/food-training-sample
# cp ../data/src_food/training/3_543.jpg ../data/food-training-sample
# cp ../data/src_food/training/3_567.jpg ../data/food-training-sample
# cp ../data/src_food/training/3_574.jpg ../data/food-training-sample
# cp ../data/src_food/training/3_578.jpg ../data/food-training-sample
# cp ../data/src_food/training/3_592.jpg ../data/food-training-sample
# cp ../data/src_food/training/3_606.jpg ../data/food-training-sample
# cp ../data/src_food/training/3_614.jpg ../data/food-training-sample
# cp ../data/src_food/training/3_623.jpg ../data/food-training-sample
# cp ../data/src_food/training/3_625.jpg ../data/food-training-sample
# cp ../data/src_food/training/3_632.jpg ../data/food-training-sample
# cp ../data/src_food/training/3_639.jpg ../data/food-training-sample
# cp ../data/src_food/training/3_63.jpg ../data/food-training-sample
# cp ../data/src_food/training/3_660.jpg ../data/food-training-sample
# cp ../data/src_food/training/3_661.jpg ../data/food-training-sample
# cp ../data/src_food/training/3_665.jpg ../data/food-training-sample
# cp ../data/src_food/training/3_668.jpg ../data/food-training-sample
# cp ../data/src_food/training/3_685.jpg ../data/food-training-sample
# cp ../data/src_food/training/3_686.jpg ../data/food-training-sample
# cp ../data/src_food/training/3_702.jpg ../data/food-training-sample
# cp ../data/src_food/training/3_718.jpg ../data/food-training-sample
# cp ../data/src_food/training/3_737.jpg ../data/food-training-sample
# cp ../data/src_food/training/3_754.jpg ../data/food-training-sample
# cp ../data/src_food/training/3_766.jpg ../data/food-training-sample
# cp ../data/src_food/training/3_767.jpg ../data/food-training-sample
# cp ../data/src_food/training/3_769.jpg ../data/food-training-sample
# cp ../data/src_food/training/3_770.jpg ../data/food-training-sample
# cp ../data/src_food/training/3_7.jpg ../data/food-training-sample
# cp ../data/src_food/training/3_810.jpg ../data/food-training-sample
# cp ../data/src_food/training/3_841.jpg ../data/food-training-sample
# cp ../data/src_food/training/3_846.jpg ../data/food-training-sample
# cp ../data/src_food/training/3_865.jpg ../data/food-training-sample
# cp ../data/src_food/training/3_868.jpg ../data/food-training-sample
# cp ../data/src_food/training/3_894.jpg ../data/food-training-sample
# cp ../data/src_food/training/3_901.jpg ../data/food-training-sample
# cp ../data/src_food/training/3_92.jpg ../data/food-training-sample
# cp ../data/src_food/training/3_962.jpg ../data/food-training-sample
# cp ../data/src_food/training/3_96.jpg ../data/food-training-sample
# cp ../data/src_food/training/3_982.jpg ../data/food-training-sample
# cp ../data/src_food/training/3_985.jpg ../data/food-training-sample
# cp ../data/src_food/training/4_102.jpg ../data/food-training-sample
# cp ../data/src_food/training/4_112.jpg ../data/food-training-sample
# cp ../data/src_food/training/4_121.jpg ../data/food-training-sample
# cp ../data/src_food/training/4_122.jpg ../data/food-training-sample
# cp ../data/src_food/training/4_123.jpg ../data/food-training-sample
# cp ../data/src_food/training/4_128.jpg ../data/food-training-sample
# cp ../data/src_food/training/4_142.jpg ../data/food-training-sample
# cp ../data/src_food/training/4_149.jpg ../data/food-training-sample
# cp ../data/src_food/training/4_152.jpg ../data/food-training-sample
# cp ../data/src_food/training/4_155.jpg ../data/food-training-sample
# cp ../data/src_food/training/4_159.jpg ../data/food-training-sample
# cp ../data/src_food/training/4_170.jpg ../data/food-training-sample
# cp ../data/src_food/training/4_173.jpg ../data/food-training-sample
# cp ../data/src_food/training/4_190.jpg ../data/food-training-sample
# cp ../data/src_food/training/4_20.jpg ../data/food-training-sample
# cp ../data/src_food/training/4_210.jpg ../data/food-training-sample
# cp ../data/src_food/training/4_211.jpg ../data/food-training-sample
# cp ../data/src_food/training/4_242.jpg ../data/food-training-sample
# cp ../data/src_food/training/4_24.jpg ../data/food-training-sample
# cp ../data/src_food/training/4_251.jpg ../data/food-training-sample
# cp ../data/src_food/training/4_255.jpg ../data/food-training-sample
# cp ../data/src_food/training/4_285.jpg ../data/food-training-sample
# cp ../data/src_food/training/4_293.jpg ../data/food-training-sample
# cp ../data/src_food/training/4_300.jpg ../data/food-training-sample
# cp ../data/src_food/training/4_301.jpg ../data/food-training-sample
# cp ../data/src_food/training/4_308.jpg ../data/food-training-sample
# cp ../data/src_food/training/4_334.jpg ../data/food-training-sample
# cp ../data/src_food/training/4_343.jpg ../data/food-training-sample
# cp ../data/src_food/training/4_359.jpg ../data/food-training-sample
# cp ../data/src_food/training/4_37.jpg ../data/food-training-sample
# cp ../data/src_food/training/4_380.jpg ../data/food-training-sample
# cp ../data/src_food/training/4_38.jpg ../data/food-training-sample
# cp ../data/src_food/training/4_398.jpg ../data/food-training-sample
# cp ../data/src_food/training/4_417.jpg ../data/food-training-sample
# cp ../data/src_food/training/4_420.jpg ../data/food-training-sample
# cp ../data/src_food/training/4_423.jpg ../data/food-training-sample
# cp ../data/src_food/training/4_44.jpg ../data/food-training-sample
# cp ../data/src_food/training/4_454.jpg ../data/food-training-sample
# cp ../data/src_food/training/4_464.jpg ../data/food-training-sample
# cp ../data/src_food/training/4_473.jpg ../data/food-training-sample
# cp ../data/src_food/training/4_474.jpg ../data/food-training-sample
# cp ../data/src_food/training/4_477.jpg ../data/food-training-sample
# cp ../data/src_food/training/4_479.jpg ../data/food-training-sample
# cp ../data/src_food/training/4_484.jpg ../data/food-training-sample
# cp ../data/src_food/training/4_487.jpg ../data/food-training-sample
# cp ../data/src_food/training/4_496.jpg ../data/food-training-sample
# cp ../data/src_food/training/4_499.jpg ../data/food-training-sample
# cp ../data/src_food/training/4_509.jpg ../data/food-training-sample
# cp ../data/src_food/training/4_510.jpg ../data/food-training-sample
# cp ../data/src_food/training/4_516.jpg ../data/food-training-sample
# cp ../data/src_food/training/4_520.jpg ../data/food-training-sample
# cp ../data/src_food/training/4_534.jpg ../data/food-training-sample
# cp ../data/src_food/training/4_540.jpg ../data/food-training-sample
# cp ../data/src_food/training/4_542.jpg ../data/food-training-sample
# cp ../data/src_food/training/4_547.jpg ../data/food-training-sample
# cp ../data/src_food/training/4_550.jpg ../data/food-training-sample
# cp ../data/src_food/training/4_551.jpg ../data/food-training-sample
# cp ../data/src_food/training/4_553.jpg ../data/food-training-sample
# cp ../data/src_food/training/4_560.jpg ../data/food-training-sample
# cp ../data/src_food/training/4_563.jpg ../data/food-training-sample
# cp ../data/src_food/training/4_579.jpg ../data/food-training-sample
# cp ../data/src_food/training/4_589.jpg ../data/food-training-sample
# cp ../data/src_food/training/4_601.jpg ../data/food-training-sample
# cp ../data/src_food/training/4_604.jpg ../data/food-training-sample
# cp ../data/src_food/training/4_613.jpg ../data/food-training-sample
# cp ../data/src_food/training/4_621.jpg ../data/food-training-sample
# cp ../data/src_food/training/4_628.jpg ../data/food-training-sample
# cp ../data/src_food/training/4_635.jpg ../data/food-training-sample
# cp ../data/src_food/training/4_648.jpg ../data/food-training-sample
# cp ../data/src_food/training/4_64.jpg ../data/food-training-sample
# cp ../data/src_food/training/4_667.jpg ../data/food-training-sample
# cp ../data/src_food/training/4_675.jpg ../data/food-training-sample
# cp ../data/src_food/training/4_677.jpg ../data/food-training-sample
# cp ../data/src_food/training/4_679.jpg ../data/food-training-sample
# cp ../data/src_food/training/4_682.jpg ../data/food-training-sample
# cp ../data/src_food/training/4_693.jpg ../data/food-training-sample
# cp ../data/src_food/training/4_695.jpg ../data/food-training-sample
# cp ../data/src_food/training/4_69.jpg ../data/food-training-sample
# cp ../data/src_food/training/4_704.jpg ../data/food-training-sample
# cp ../data/src_food/training/4_715.jpg ../data/food-training-sample
# cp ../data/src_food/training/4_71.jpg ../data/food-training-sample
# cp ../data/src_food/training/4_728.jpg ../data/food-training-sample
# cp ../data/src_food/training/4_738.jpg ../data/food-training-sample
# cp ../data/src_food/training/4_741.jpg ../data/food-training-sample
# cp ../data/src_food/training/4_744.jpg ../data/food-training-sample
# cp ../data/src_food/training/4_749.jpg ../data/food-training-sample
# cp ../data/src_food/training/4_760.jpg ../data/food-training-sample
# cp ../data/src_food/training/4_766.jpg ../data/food-training-sample
# cp ../data/src_food/training/4_76.jpg ../data/food-training-sample
# cp ../data/src_food/training/4_80.jpg ../data/food-training-sample
# cp ../data/src_food/training/4_814.jpg ../data/food-training-sample
# cp ../data/src_food/training/4_830.jpg ../data/food-training-sample
# cp ../data/src_food/training/4_831.jpg ../data/food-training-sample
# cp ../data/src_food/training/4_833.jpg ../data/food-training-sample
# cp ../data/src_food/training/4_835.jpg ../data/food-training-sample
# cp ../data/src_food/training/4_83.jpg ../data/food-training-sample
# cp ../data/src_food/training/4_843.jpg ../data/food-training-sample
# cp ../data/src_food/training/4_84.jpg ../data/food-training-sample
# cp ../data/src_food/training/4_86.jpg ../data/food-training-sample
# cp ../data/src_food/training/4_95.jpg ../data/food-training-sample
# cp ../data/src_food/training/5_1009.jpg ../data/food-training-sample
# cp ../data/src_food/training/5_100.jpg ../data/food-training-sample
# cp ../data/src_food/training/5_1022.jpg ../data/food-training-sample
# cp ../data/src_food/training/5_1055.jpg ../data/food-training-sample
# cp ../data/src_food/training/5_1065.jpg ../data/food-training-sample
# cp ../data/src_food/training/5_1075.jpg ../data/food-training-sample
# cp ../data/src_food/training/5_1080.jpg ../data/food-training-sample
# cp ../data/src_food/training/5_1082.jpg ../data/food-training-sample
# cp ../data/src_food/training/5_1090.jpg ../data/food-training-sample
# cp ../data/src_food/training/5_1104.jpg ../data/food-training-sample
# cp ../data/src_food/training/5_1108.jpg ../data/food-training-sample
# cp ../data/src_food/training/5_1109.jpg ../data/food-training-sample
# cp ../data/src_food/training/5_1126.jpg ../data/food-training-sample
# cp ../data/src_food/training/5_1137.jpg ../data/food-training-sample
# cp ../data/src_food/training/5_1158.jpg ../data/food-training-sample
# cp ../data/src_food/training/5_1166.jpg ../data/food-training-sample
# cp ../data/src_food/training/5_1178.jpg ../data/food-training-sample
# cp ../data/src_food/training/5_1216.jpg ../data/food-training-sample
# cp ../data/src_food/training/5_1219.jpg ../data/food-training-sample
# cp ../data/src_food/training/5_1221.jpg ../data/food-training-sample
# cp ../data/src_food/training/5_1232.jpg ../data/food-training-sample
# cp ../data/src_food/training/5_1245.jpg ../data/food-training-sample
# cp ../data/src_food/training/5_1247.jpg ../data/food-training-sample
# cp ../data/src_food/training/5_1250.jpg ../data/food-training-sample
# cp ../data/src_food/training/5_1260.jpg ../data/food-training-sample
# cp ../data/src_food/training/5_1274.jpg ../data/food-training-sample
# cp ../data/src_food/training/5_1276.jpg ../data/food-training-sample
# cp ../data/src_food/training/5_1277.jpg ../data/food-training-sample
# cp ../data/src_food/training/5_1298.jpg ../data/food-training-sample
# cp ../data/src_food/training/5_1318.jpg ../data/food-training-sample
# cp ../data/src_food/training/5_134.jpg ../data/food-training-sample
# cp ../data/src_food/training/5_145.jpg ../data/food-training-sample
# cp ../data/src_food/training/5_154.jpg ../data/food-training-sample
# cp ../data/src_food/training/5_163.jpg ../data/food-training-sample
# cp ../data/src_food/training/5_176.jpg ../data/food-training-sample
# cp ../data/src_food/training/5_181.jpg ../data/food-training-sample
# cp ../data/src_food/training/5_184.jpg ../data/food-training-sample
# cp ../data/src_food/training/5_186.jpg ../data/food-training-sample
# cp ../data/src_food/training/5_188.jpg ../data/food-training-sample
# cp ../data/src_food/training/5_18.jpg ../data/food-training-sample
# cp ../data/src_food/training/5_209.jpg ../data/food-training-sample
# cp ../data/src_food/training/5_214.jpg ../data/food-training-sample
# cp ../data/src_food/training/5_23.jpg ../data/food-training-sample
# cp ../data/src_food/training/5_249.jpg ../data/food-training-sample
# cp ../data/src_food/training/5_250.jpg ../data/food-training-sample
# cp ../data/src_food/training/5_257.jpg ../data/food-training-sample
# cp ../data/src_food/training/5_267.jpg ../data/food-training-sample
# cp ../data/src_food/training/5_273.jpg ../data/food-training-sample
# cp ../data/src_food/training/5_289.jpg ../data/food-training-sample
# cp ../data/src_food/training/5_296.jpg ../data/food-training-sample
# cp ../data/src_food/training/5_298.jpg ../data/food-training-sample
# cp ../data/src_food/training/5_307.jpg ../data/food-training-sample
# cp ../data/src_food/training/5_315.jpg ../data/food-training-sample
# cp ../data/src_food/training/5_374.jpg ../data/food-training-sample
# cp ../data/src_food/training/5_376.jpg ../data/food-training-sample
# cp ../data/src_food/training/5_37.jpg ../data/food-training-sample
# cp ../data/src_food/training/5_3.jpg ../data/food-training-sample
# cp ../data/src_food/training/5_409.jpg ../data/food-training-sample
# cp ../data/src_food/training/5_424.jpg ../data/food-training-sample
# cp ../data/src_food/training/5_435.jpg ../data/food-training-sample
# cp ../data/src_food/training/5_439.jpg ../data/food-training-sample
# cp ../data/src_food/training/5_467.jpg ../data/food-training-sample
# cp ../data/src_food/training/5_46.jpg ../data/food-training-sample
# cp ../data/src_food/training/5_477.jpg ../data/food-training-sample
# cp ../data/src_food/training/5_484.jpg ../data/food-training-sample
# cp ../data/src_food/training/5_502.jpg ../data/food-training-sample
# cp ../data/src_food/training/5_505.jpg ../data/food-training-sample
# cp ../data/src_food/training/5_510.jpg ../data/food-training-sample
# cp ../data/src_food/training/5_515.jpg ../data/food-training-sample
# cp ../data/src_food/training/5_518.jpg ../data/food-training-sample
# cp ../data/src_food/training/5_520.jpg ../data/food-training-sample
# cp ../data/src_food/training/5_527.jpg ../data/food-training-sample
# cp ../data/src_food/training/5_564.jpg ../data/food-training-sample
# cp ../data/src_food/training/5_565.jpg ../data/food-training-sample
# cp ../data/src_food/training/5_59.jpg ../data/food-training-sample
# cp ../data/src_food/training/5_605.jpg ../data/food-training-sample
# cp ../data/src_food/training/5_647.jpg ../data/food-training-sample
# cp ../data/src_food/training/5_663.jpg ../data/food-training-sample
# cp ../data/src_food/training/5_667.jpg ../data/food-training-sample
# cp ../data/src_food/training/5_678.jpg ../data/food-training-sample
# cp ../data/src_food/training/5_736.jpg ../data/food-training-sample
# cp ../data/src_food/training/5_738.jpg ../data/food-training-sample
# cp ../data/src_food/training/5_742.jpg ../data/food-training-sample
# cp ../data/src_food/training/5_744.jpg ../data/food-training-sample
# cp ../data/src_food/training/5_74.jpg ../data/food-training-sample
# cp ../data/src_food/training/5_757.jpg ../data/food-training-sample
# cp ../data/src_food/training/5_765.jpg ../data/food-training-sample
# cp ../data/src_food/training/5_790.jpg ../data/food-training-sample
# cp ../data/src_food/training/5_803.jpg ../data/food-training-sample
# cp ../data/src_food/training/5_811.jpg ../data/food-training-sample
# cp ../data/src_food/training/5_813.jpg ../data/food-training-sample
# cp ../data/src_food/training/5_819.jpg ../data/food-training-sample
# cp ../data/src_food/training/5_875.jpg ../data/food-training-sample
# cp ../data/src_food/training/5_876.jpg ../data/food-training-sample
# cp ../data/src_food/training/5_888.jpg ../data/food-training-sample
# cp ../data/src_food/training/5_89.jpg ../data/food-training-sample
# cp ../data/src_food/training/5_905.jpg ../data/food-training-sample
# cp ../data/src_food/training/5_907.jpg ../data/food-training-sample
# cp ../data/src_food/training/5_955.jpg ../data/food-training-sample
# cp ../data/src_food/training/5_992.jpg ../data/food-training-sample
# cp ../data/src_food/training/6_0.jpg ../data/food-training-sample
# cp ../data/src_food/training/6_101.jpg ../data/food-training-sample
# cp ../data/src_food/training/6_109.jpg ../data/food-training-sample
# cp ../data/src_food/training/6_113.jpg ../data/food-training-sample
# cp ../data/src_food/training/6_114.jpg ../data/food-training-sample
# cp ../data/src_food/training/6_116.jpg ../data/food-training-sample
# cp ../data/src_food/training/6_118.jpg ../data/food-training-sample
# cp ../data/src_food/training/6_121.jpg ../data/food-training-sample
# cp ../data/src_food/training/6_122.jpg ../data/food-training-sample
# cp ../data/src_food/training/6_129.jpg ../data/food-training-sample
# cp ../data/src_food/training/6_131.jpg ../data/food-training-sample
# cp ../data/src_food/training/6_132.jpg ../data/food-training-sample
# cp ../data/src_food/training/6_135.jpg ../data/food-training-sample
# cp ../data/src_food/training/6_136.jpg ../data/food-training-sample
# cp ../data/src_food/training/6_148.jpg ../data/food-training-sample
# cp ../data/src_food/training/6_152.jpg ../data/food-training-sample
# cp ../data/src_food/training/6_162.jpg ../data/food-training-sample
# cp ../data/src_food/training/6_163.jpg ../data/food-training-sample
# cp ../data/src_food/training/6_172.jpg ../data/food-training-sample
# cp ../data/src_food/training/6_178.jpg ../data/food-training-sample
# cp ../data/src_food/training/6_189.jpg ../data/food-training-sample
# cp ../data/src_food/training/6_18.jpg ../data/food-training-sample
# cp ../data/src_food/training/6_190.jpg ../data/food-training-sample
# cp ../data/src_food/training/6_191.jpg ../data/food-training-sample
# cp ../data/src_food/training/6_201.jpg ../data/food-training-sample
# cp ../data/src_food/training/6_204.jpg ../data/food-training-sample
# cp ../data/src_food/training/6_209.jpg ../data/food-training-sample
# cp ../data/src_food/training/6_217.jpg ../data/food-training-sample
# cp ../data/src_food/training/6_220.jpg ../data/food-training-sample
# cp ../data/src_food/training/6_221.jpg ../data/food-training-sample
# cp ../data/src_food/training/6_228.jpg ../data/food-training-sample
# cp ../data/src_food/training/6_229.jpg ../data/food-training-sample
# cp ../data/src_food/training/6_22.jpg ../data/food-training-sample
# cp ../data/src_food/training/6_230.jpg ../data/food-training-sample
# cp ../data/src_food/training/6_231.jpg ../data/food-training-sample
# cp ../data/src_food/training/6_232.jpg ../data/food-training-sample
# cp ../data/src_food/training/6_242.jpg ../data/food-training-sample
# cp ../data/src_food/training/6_244.jpg ../data/food-training-sample
# cp ../data/src_food/training/6_24.jpg ../data/food-training-sample
# cp ../data/src_food/training/6_250.jpg ../data/food-training-sample
# cp ../data/src_food/training/6_255.jpg ../data/food-training-sample
# cp ../data/src_food/training/6_263.jpg ../data/food-training-sample
# cp ../data/src_food/training/6_264.jpg ../data/food-training-sample
# cp ../data/src_food/training/6_266.jpg ../data/food-training-sample
# cp ../data/src_food/training/6_269.jpg ../data/food-training-sample
# cp ../data/src_food/training/6_273.jpg ../data/food-training-sample
# cp ../data/src_food/training/6_274.jpg ../data/food-training-sample
# cp ../data/src_food/training/6_286.jpg ../data/food-training-sample
# cp ../data/src_food/training/6_287.jpg ../data/food-training-sample
# cp ../data/src_food/training/6_288.jpg ../data/food-training-sample
# cp ../data/src_food/training/6_289.jpg ../data/food-training-sample
# cp ../data/src_food/training/6_28.jpg ../data/food-training-sample
# cp ../data/src_food/training/6_293.jpg ../data/food-training-sample
# cp ../data/src_food/training/6_295.jpg ../data/food-training-sample
# cp ../data/src_food/training/6_299.jpg ../data/food-training-sample
# cp ../data/src_food/training/6_307.jpg ../data/food-training-sample
# cp ../data/src_food/training/6_316.jpg ../data/food-training-sample
# cp ../data/src_food/training/6_31.jpg ../data/food-training-sample
# cp ../data/src_food/training/6_320.jpg ../data/food-training-sample
# cp ../data/src_food/training/6_322.jpg ../data/food-training-sample
# cp ../data/src_food/training/6_326.jpg ../data/food-training-sample
# cp ../data/src_food/training/6_333.jpg ../data/food-training-sample
# cp ../data/src_food/training/6_341.jpg ../data/food-training-sample
# cp ../data/src_food/training/6_344.jpg ../data/food-training-sample
# cp ../data/src_food/training/6_347.jpg ../data/food-training-sample
# cp ../data/src_food/training/6_352.jpg ../data/food-training-sample
# cp ../data/src_food/training/6_353.jpg ../data/food-training-sample
# cp ../data/src_food/training/6_359.jpg ../data/food-training-sample
# cp ../data/src_food/training/6_362.jpg ../data/food-training-sample
# cp ../data/src_food/training/6_364.jpg ../data/food-training-sample
# cp ../data/src_food/training/6_365.jpg ../data/food-training-sample
# cp ../data/src_food/training/6_367.jpg ../data/food-training-sample
# cp ../data/src_food/training/6_369.jpg ../data/food-training-sample
# cp ../data/src_food/training/6_372.jpg ../data/food-training-sample
# cp ../data/src_food/training/6_376.jpg ../data/food-training-sample
# cp ../data/src_food/training/6_37.jpg ../data/food-training-sample
# cp ../data/src_food/training/6_385.jpg ../data/food-training-sample
# cp ../data/src_food/training/6_387.jpg ../data/food-training-sample
# cp ../data/src_food/training/6_399.jpg ../data/food-training-sample
# cp ../data/src_food/training/6_410.jpg ../data/food-training-sample
# cp ../data/src_food/training/6_414.jpg ../data/food-training-sample
# cp ../data/src_food/training/6_415.jpg ../data/food-training-sample
# cp ../data/src_food/training/6_419.jpg ../data/food-training-sample
# cp ../data/src_food/training/6_41.jpg ../data/food-training-sample
# cp ../data/src_food/training/6_424.jpg ../data/food-training-sample
# cp ../data/src_food/training/6_428.jpg ../data/food-training-sample
# cp ../data/src_food/training/6_43.jpg ../data/food-training-sample
# cp ../data/src_food/training/6_48.jpg ../data/food-training-sample
# cp ../data/src_food/training/6_54.jpg ../data/food-training-sample
# cp ../data/src_food/training/6_61.jpg ../data/food-training-sample
# cp ../data/src_food/training/6_64.jpg ../data/food-training-sample
# cp ../data/src_food/training/6_66.jpg ../data/food-training-sample
# cp ../data/src_food/training/6_68.jpg ../data/food-training-sample
# cp ../data/src_food/training/6_74.jpg ../data/food-training-sample
# cp ../data/src_food/training/6_76.jpg ../data/food-training-sample
# cp ../data/src_food/training/6_84.jpg ../data/food-training-sample
# cp ../data/src_food/training/6_85.jpg ../data/food-training-sample
# cp ../data/src_food/training/6_89.jpg ../data/food-training-sample
# cp ../data/src_food/training/6_90.jpg ../data/food-training-sample
# cp ../data/src_food/training/6_92.jpg ../data/food-training-sample
# cp ../data/src_food/training/7_103.jpg ../data/food-training-sample
# cp ../data/src_food/training/7_105.jpg ../data/food-training-sample
# cp ../data/src_food/training/7_111.jpg ../data/food-training-sample
# cp ../data/src_food/training/7_112.jpg ../data/food-training-sample
# cp ../data/src_food/training/7_113.jpg ../data/food-training-sample
# cp ../data/src_food/training/7_126.jpg ../data/food-training-sample
# ...
# cp ../data/src_food/training/8_631.jpg ../data/food-training-sample
# cp ../data/src_food/training/8_633.jpg ../data/food-training-sample
# cp ../data/src_food/training/8_641.jpg ../data/food-training-sample
# cp ../data/src_food/training/8_644.jpg ../data/food-training-sample
# cp ../data/src_food/training/8_647.jpg ../data/food-training-sample
# cp ../data/src_food/training/8_648.jpg ../data/food-training-sample
# cp ../data/src_food/training/8_649.jpg ../data/food-training-sample
# cp ../data/src_food/training/8_657.jpg ../data/food-training-sample
# cp ../data/src_food/training/8_667.jpg ../data/food-training-sample
# cp ../data/src_food/training/8_680.jpg ../data/food-training-sample
# cp ../data/src_food/training/8_684.jpg ../data/food-training-sample
# cp ../data/src_food/training/8_686.jpg ../data/food-training-sample
# cp ../data/src_food/training/8_687.jpg ../data/food-training-sample
# cp ../data/src_food/training/8_68.jpg ../data/food-training-sample
# cp ../data/src_food/training/8_694.jpg ../data/food-training-sample
# cp ../data/src_food/training/8_701.jpg ../data/food-training-sample
# cp ../data/src_food/training/8_707.jpg ../data/food-training-sample
# cp ../data/src_food/training/8_708.jpg ../data/food-training-sample
# cp ../data/src_food/training/8_709.jpg ../data/food-training-sample
# cp ../data/src_food/training/8_716.jpg ../data/food-training-sample
# cp ../data/src_food/training/8_725.jpg ../data/food-training-sample
# cp ../data/src_food/training/8_739.jpg ../data/food-training-sample
# cp ../data/src_food/training/8_750.jpg ../data/food-training-sample
# cp ../data/src_food/training/8_778.jpg ../data/food-training-sample
# cp ../data/src_food/training/8_786.jpg ../data/food-training-sample
# cp ../data/src_food/training/8_790.jpg ../data/food-training-sample
# cp ../data/src_food/training/8_796.jpg ../data/food-training-sample
# cp ../data/src_food/training/8_802.jpg ../data/food-training-sample
# cp ../data/src_food/training/8_817.jpg ../data/food-training-sample
# cp ../data/src_food/training/8_825.jpg ../data/food-training-sample
# cp ../data/src_food/training/8_843.jpg ../data/food-training-sample
# cp ../data/src_food/training/8_846.jpg ../data/food-training-sample
# cp ../data/src_food/training/8_8.jpg ../data/food-training-sample
# cp ../data/src_food/training/9_1007.jpg ../data/food-training-sample
# cp ../data/src_food/training/9_1011.jpg ../data/food-training-sample
# cp ../data/src_food/training/9_1058.jpg ../data/food-training-sample
# cp ../data/src_food/training/9_1068.jpg ../data/food-training-sample
# cp ../data/src_food/training/9_1100.jpg ../data/food-training-sample
# cp ../data/src_food/training/9_113.jpg ../data/food-training-sample
# cp ../data/src_food/training/9_1164.jpg ../data/food-training-sample
# cp ../data/src_food/training/9_1223.jpg ../data/food-training-sample
# cp ../data/src_food/training/9_1225.jpg ../data/food-training-sample
# cp ../data/src_food/training/9_1236.jpg ../data/food-training-sample
# cp ../data/src_food/training/9_1255.jpg ../data/food-training-sample
# cp ../data/src_food/training/9_1258.jpg ../data/food-training-sample
# cp ../data/src_food/training/9_1280.jpg ../data/food-training-sample
# cp ../data/src_food/training/9_1282.jpg ../data/food-training-sample
# cp ../data/src_food/training/9_1290.jpg ../data/food-training-sample
# cp ../data/src_food/training/9_1293.jpg ../data/food-training-sample
# cp ../data/src_food/training/9_130.jpg ../data/food-training-sample
# cp ../data/src_food/training/9_1317.jpg ../data/food-training-sample
# cp ../data/src_food/training/9_1321.jpg ../data/food-training-sample
# cp ../data/src_food/training/9_1327.jpg ../data/food-training-sample
# cp ../data/src_food/training/9_1394.jpg ../data/food-training-sample
# cp ../data/src_food/training/9_1399.jpg ../data/food-training-sample
# cp ../data/src_food/training/9_1400.jpg ../data/food-training-sample
# cp ../data/src_food/training/9_1402.jpg ../data/food-training-sample
# cp ../data/src_food/training/9_1405.jpg ../data/food-training-sample
# cp ../data/src_food/training/9_1409.jpg ../data/food-training-sample
# cp ../data/src_food/training/9_140.jpg ../data/food-training-sample
# cp ../data/src_food/training/9_1431.jpg ../data/food-training-sample
# cp ../data/src_food/training/9_1436.jpg ../data/food-training-sample
# cp ../data/src_food/training/9_1486.jpg ../data/food-training-sample
# cp ../data/src_food/training/9_173.jpg ../data/food-training-sample
# cp ../data/src_food/training/9_197.jpg ../data/food-training-sample
# cp ../data/src_food/training/9_203.jpg ../data/food-training-sample
# cp ../data/src_food/training/9_222.jpg ../data/food-training-sample
# cp ../data/src_food/training/9_231.jpg ../data/food-training-sample
# cp ../data/src_food/training/9_236.jpg ../data/food-training-sample
# cp ../data/src_food/training/9_25.jpg ../data/food-training-sample
# cp ../data/src_food/training/9_282.jpg ../data/food-training-sample
# cp ../data/src_food/training/9_288.jpg ../data/food-training-sample
# cp ../data/src_food/training/9_289.jpg ../data/food-training-sample
# cp ../data/src_food/training/9_304.jpg ../data/food-training-sample
# cp ../data/src_food/training/9_338.jpg ../data/food-training-sample
# cp ../data/src_food/training/9_345.jpg ../data/food-training-sample
# cp ../data/src_food/training/9_388.jpg ../data/food-training-sample
# cp ../data/src_food/training/9_390.jpg ../data/food-training-sample
# cp ../data/src_food/training/9_406.jpg ../data/food-training-sample
# cp ../data/src_food/training/9_409.jpg ../data/food-training-sample
# cp ../data/src_food/training/9_410.jpg ../data/food-training-sample
# cp ../data/src_food/training/9_415.jpg ../data/food-training-sample
# cp ../data/src_food/training/9_428.jpg ../data/food-training-sample
# cp ../data/src_food/training/9_439.jpg ../data/food-training-sample
# cp ../data/src_food/training/9_444.jpg ../data/food-training-sample
# cp ../data/src_food/training/9_459.jpg ../data/food-training-sample
# cp ../data/src_food/training/9_461.jpg ../data/food-training-sample
# cp ../data/src_food/training/9_464.jpg ../data/food-training-sample
# cp ../data/src_food/training/9_482.jpg ../data/food-training-sample
# cp ../data/src_food/training/9_510.jpg ../data/food-training-sample
# cp ../data/src_food/training/9_524.jpg ../data/food-training-sample
# cp ../data/src_food/training/9_52.jpg ../data/food-training-sample
# cp ../data/src_food/training/9_533.jpg ../data/food-training-sample
# cp ../data/src_food/training/9_542.jpg ../data/food-training-sample
# cp ../data/src_food/training/9_552.jpg ../data/food-training-sample
# cp ../data/src_food/training/9_565.jpg ../data/food-training-sample
# cp ../data/src_food/training/9_56.jpg ../data/food-training-sample
# cp ../data/src_food/training/9_594.jpg ../data/food-training-sample
# cp ../data/src_food/training/9_598.jpg ../data/food-training-sample
# cp ../data/src_food/training/9_604.jpg ../data/food-training-sample
# cp ../data/src_food/training/9_606.jpg ../data/food-training-sample
# cp ../data/src_food/training/9_607.jpg ../data/food-training-sample
# cp ../data/src_food/training/9_631.jpg ../data/food-training-sample
# cp ../data/src_food/training/9_633.jpg ../data/food-training-sample
# cp ../data/src_food/training/9_637.jpg ../data/food-training-sample
# cp ../data/src_food/training/9_639.jpg ../data/food-training-sample
# cp ../data/src_food/training/9_645.jpg ../data/food-training-sample
# cp ../data/src_food/training/9_654.jpg ../data/food-training-sample
# cp ../data/src_food/training/9_658.jpg ../data/food-training-sample
# cp ../data/src_food/training/9_695.jpg ../data/food-training-sample
# cp ../data/src_food/training/9_698.jpg ../data/food-training-sample
# cp ../data/src_food/training/9_735.jpg ../data/food-training-sample
# cp ../data/src_food/training/9_740.jpg ../data/food-training-sample
# cp ../data/src_food/training/9_741.jpg ../data/food-training-sample
# cp ../data/src_food/training/9_74.jpg ../data/food-training-sample
# cp ../data/src_food/training/9_761.jpg ../data/food-training-sample
# cp ../data/src_food/training/9_76.jpg ../data/food-training-sample
# cp ../data/src_food/training/9_801.jpg ../data/food-training-sample
# cp ../data/src_food/training/9_822.jpg ../data/food-training-sample
# cp ../data/src_food/training/9_828.jpg ../data/food-training-sample
# cp ../data/src_food/training/9_859.jpg ../data/food-training-sample
# cp ../data/src_food/training/9_87.jpg ../data/food-training-sample
# cp ../data/src_food/training/9_882.jpg ../data/food-training-sample
# cp ../data/src_food/training/9_897.jpg ../data/food-training-sample
# cp ../data/src_food/training/9_89.jpg ../data/food-training-sample
# cp ../data/src_food/training/9_912.jpg ../data/food-training-sample
# cp ../data/src_food/training/9_918.jpg ../data/food-training-sample
# cp ../data/src_food/training/9_919.jpg ../data/food-training-sample
# cp ../data/src_food/training/9_925.jpg ../data/food-training-sample
# cp ../data/src_food/training/9_927.jpg ../data/food-training-sample
# cp ../data/src_food/training/9_954.jpg ../data/food-training-sample
# cp ../data/src_food/training/9_955.jpg ../data/food-training-sample
# cp ../data/src_food/training/9_969.jpg ../data/food-training-sample
# cp ../data/src_food/training/10_105.jpg ../data/food-training-sample
# cp ../data/src_food/training/10_121.jpg ../data/food-training-sample
# cp ../data/src_food/training/10_131.jpg ../data/food-training-sample
# cp ../data/src_food/training/10_141.jpg ../data/food-training-sample
# cp ../data/src_food/training/10_145.jpg ../data/food-training-sample
# cp ../data/src_food/training/10_148.jpg ../data/food-training-sample
# cp ../data/src_food/training/10_149.jpg ../data/food-training-sample
# cp ../data/src_food/training/10_153.jpg ../data/food-training-sample
# cp ../data/src_food/training/10_156.jpg ../data/food-training-sample
# cp ../data/src_food/training/10_177.jpg ../data/food-training-sample
# cp ../data/src_food/training/10_185.jpg ../data/food-training-sample
# cp ../data/src_food/training/10_193.jpg ../data/food-training-sample
# cp ../data/src_food/training/10_195.jpg ../data/food-training-sample
# cp ../data/src_food/training/10_198.jpg ../data/food-training-sample
# cp ../data/src_food/training/10_199.jpg ../data/food-training-sample
# cp ../data/src_food/training/10_208.jpg ../data/food-training-sample
# cp ../data/src_food/training/10_20.jpg ../data/food-training-sample
# cp ../data/src_food/training/10_215.jpg ../data/food-training-sample
# cp ../data/src_food/training/10_229.jpg ../data/food-training-sample
# cp ../data/src_food/training/10_245.jpg ../data/food-training-sample
# cp ../data/src_food/training/10_249.jpg ../data/food-training-sample
# cp ../data/src_food/training/10_24.jpg ../data/food-training-sample
# cp ../data/src_food/training/10_256.jpg ../data/food-training-sample
# cp ../data/src_food/training/10_257.jpg ../data/food-training-sample
# cp ../data/src_food/training/10_259.jpg ../data/food-training-sample
# cp ../data/src_food/training/10_270.jpg ../data/food-training-sample
# cp ../data/src_food/training/10_27.jpg ../data/food-training-sample
# cp ../data/src_food/training/10_287.jpg ../data/food-training-sample
# cp ../data/src_food/training/10_288.jpg ../data/food-training-sample
# cp ../data/src_food/training/10_295.jpg ../data/food-training-sample
# cp ../data/src_food/training/10_2.jpg ../data/food-training-sample
# cp ../data/src_food/training/10_310.jpg ../data/food-training-sample
# cp ../data/src_food/training/10_314.jpg ../data/food-training-sample
# cp ../data/src_food/training/10_315.jpg ../data/food-training-sample
# cp ../data/src_food/training/10_318.jpg ../data/food-training-sample
# cp ../data/src_food/training/10_321.jpg ../data/food-training-sample
# cp ../data/src_food/training/10_324.jpg ../data/food-training-sample
# cp ../data/src_food/training/10_325.jpg ../data/food-training-sample
# cp ../data/src_food/training/10_33.jpg ../data/food-training-sample
# cp ../data/src_food/training/10_345.jpg ../data/food-training-sample
# cp ../data/src_food/training/10_34.jpg ../data/food-training-sample
# cp ../data/src_food/training/10_360.jpg ../data/food-training-sample
# cp ../data/src_food/training/10_370.jpg ../data/food-training-sample
# cp ../data/src_food/training/10_374.jpg ../data/food-training-sample
# cp ../data/src_food/training/10_376.jpg ../data/food-training-sample
# cp ../data/src_food/training/10_380.jpg ../data/food-training-sample
# cp ../data/src_food/training/10_381.jpg ../data/food-training-sample
# cp ../data/src_food/training/10_399.jpg ../data/food-training-sample
# cp ../data/src_food/training/10_40.jpg ../data/food-training-sample
# cp ../data/src_food/training/10_428.jpg ../data/food-training-sample
# cp ../data/src_food/training/10_429.jpg ../data/food-training-sample
# cp ../data/src_food/training/10_441.jpg ../data/food-training-sample
# cp ../data/src_food/training/10_442.jpg ../data/food-training-sample
# cp ../data/src_food/training/10_443.jpg ../data/food-training-sample
# cp ../data/src_food/training/10_447.jpg ../data/food-training-sample
# cp ../data/src_food/training/10_449.jpg ../data/food-training-sample
# cp ../data/src_food/training/10_44.jpg ../data/food-training-sample
# cp ../data/src_food/training/10_457.jpg ../data/food-training-sample
# cp ../data/src_food/training/10_459.jpg ../data/food-training-sample
# cp ../data/src_food/training/10_466.jpg ../data/food-training-sample
# cp ../data/src_food/training/10_470.jpg ../data/food-training-sample
# cp ../data/src_food/training/10_484.jpg ../data/food-training-sample
# cp ../data/src_food/training/10_486.jpg ../data/food-training-sample
# cp ../data/src_food/training/10_487.jpg ../data/food-training-sample
# cp ../data/src_food/training/10_488.jpg ../data/food-training-sample
# cp ../data/src_food/training/10_493.jpg ../data/food-training-sample
# cp ../data/src_food/training/10_497.jpg ../data/food-training-sample
# cp ../data/src_food/training/10_49.jpg ../data/food-training-sample
# cp ../data/src_food/training/10_534.jpg ../data/food-training-sample
# cp ../data/src_food/training/10_538.jpg ../data/food-training-sample
# cp ../data/src_food/training/10_548.jpg ../data/food-training-sample
# cp ../data/src_food/training/10_553.jpg ../data/food-training-sample
# cp ../data/src_food/training/10_561.jpg ../data/food-training-sample
# cp ../data/src_food/training/10_566.jpg ../data/food-training-sample
# cp ../data/src_food/training/10_573.jpg ../data/food-training-sample
# cp ../data/src_food/training/10_576.jpg ../data/food-training-sample
# cp ../data/src_food/training/10_578.jpg ../data/food-training-sample
# cp ../data/src_food/training/10_588.jpg ../data/food-training-sample
# cp ../data/src_food/training/10_58.jpg ../data/food-training-sample
# cp ../data/src_food/training/10_596.jpg ../data/food-training-sample
# cp ../data/src_food/training/10_607.jpg ../data/food-training-sample
# cp ../data/src_food/training/10_611.jpg ../data/food-training-sample
# cp ../data/src_food/training/10_617.jpg ../data/food-training-sample
# cp ../data/src_food/training/10_624.jpg ../data/food-training-sample
# cp ../data/src_food/training/10_642.jpg ../data/food-training-sample
# cp ../data/src_food/training/10_646.jpg ../data/food-training-sample
# cp ../data/src_food/training/10_64.jpg ../data/food-training-sample
# cp ../data/src_food/training/10_651.jpg ../data/food-training-sample
# cp ../data/src_food/training/10_653.jpg ../data/food-training-sample
# cp ../data/src_food/training/10_657.jpg ../data/food-training-sample
# cp ../data/src_food/training/10_661.jpg ../data/food-training-sample
# cp ../data/src_food/training/10_666.jpg ../data/food-training-sample
# cp ../data/src_food/training/10_667.jpg ../data/food-training-sample
# cp ../data/src_food/training/10_681.jpg ../data/food-training-sample
# cp ../data/src_food/training/10_699.jpg ../data/food-training-sample
# cp ../data/src_food/training/10_78.jpg ../data/food-training-sample
# cp ../data/src_food/training/10_88.jpg ../data/food-training-sample
# cp ../data/src_food/training/10_90.jpg ../data/food-training-sample
# cp ../data/src_food/training/10_91.jpg ../data/food-training-sample
# cp ../data/src_food/training/10_96.jpg ../data/food-training-sample

# %% [markdown]
# Load Data
# ---------
#
# We will use torchvision and torch.utils.data packages for loading the
# data.
#
# The problem we're going to solve today is to train a model to classify
# **ants** and **bees**. We have about 120 training images each for ants and bees.
# There are 75 validation images for each class. Usually, this is a very
# small dataset to generalize upon, if trained from scratch. Since we
# are using transfer learning, we should be able to generalize reasonably
# well.
#
# This dataset is a very small subset of imagenet.
#
# .. Note ::
#    Download the data from
#    `here <https://download.pytorch.org/tutorial/hymenoptera_data.zip>`_
#    and extract it to the current directory.

# %%
# Data augmentation and normalization for training
# Just normalization for validation
data_transforms = {
    'train-sample': transforms.Compose([
        transforms.RandomResizedCrop(224),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
        transforms.Normalize([0.5548, 0.4508, 0.3435], [0.2281, 0.2384, 0.2376])
    ]),
    'val': transforms.Compose([
        transforms.Resize(256),
        transforms.CenterCrop(224),
        transforms.ToTensor(),
        transforms.Normalize([0.5604, 0.4540, 0.3481], [0.2260, 0.2367, 0.2352])
    ]),
    'test': transforms.Compose([
        transforms.Resize(256),
        transforms.CenterCrop(224),
        transforms.ToTensor(),
        transforms.Normalize([0.5604, 0.4540, 0.3481], [0.2260, 0.2367, 0.2352])
    ]),
}

data_dir = '../data/food/'
image_datasets = {x: datasets.ImageFolder(os.path.join(data_dir, x),
                                          data_transforms[x])
                  for x in ['train-sample', 'val', 'test']}
dataloaders = {x: torch.utils.data.DataLoader(image_datasets[x], batch_size=4,
                                             shuffle=True, num_workers=1)
              for x in ['train-sample', 'val', 'test']}
dataset_sizes = {x: len(image_datasets[x]) for x in ['train-sample', 'val', 'test']}
class_names = image_datasets['train-sample'].classes
print(class_names)

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
#device = torch.device("cpu")
# Out:
# ['0', '1', '10', '2', '3', '4', '5', '6', '7', '8', '9']

# %% [markdown]
# Visualize a few images
# ^^^^^^^^^^^^^^^^^^^^^^
# Let's visualize a few training images so as to understand the data
# augmentations.

# %%
def imshow(inp, title=None):
    """Imshow for Tensor."""
    inp = inp.numpy().transpose((1, 2, 0))
    mean = np.array([0.5548, 0.4508, 0.3435])
    std = np.array([0.2281, 0.2384, 0.2376])
    inp = std * inp + mean
    inp = np.clip(inp, 0, 1)
    plt.imshow(inp)
    if title is not None:
        plt.title(title)
    plt.pause(0.001)  # pause a bit so that plots are updated


# Get a batch of training data
inputs, classes = next(iter(dataloaders['train-sample']))

print(classes)

# Make a grid from batch
out = torchvision.utils.make_grid(inputs)

imshow(out, title=[class_names[x] for x in classes])
# Out:
# tensor([2, 2, 4, 7])

# %% [markdown]
# Training the model
# ------------------
#
# Now, let's write a general function to train a model. Here, we will
# illustrate:
#
# -  Scheduling the learning rate
# -  Saving the best model
#
# In the following, parameter ``scheduler`` is an LR scheduler object from
# ``torch.optim.lr_scheduler``.

# %%
def train_model(model, criterion, optimizer, scheduler, num_epochs=25):
    since = time.time()

    best_model_wts = copy.deepcopy(model.state_dict())
    best_acc = 0.0

    for epoch in range(num_epochs):
        print('Epoch {}/{}'.format(epoch, num_epochs - 1))
        print('-' * 10)

        # Each epoch has a training and validation phase
        for phase in ['train-sample', 'val']:
            if phase == 'train-sample':
                scheduler.step()
                model.train()  # Set model to training mode
            else:
                model.eval()   # Set model to evaluate mode

            running_loss = 0.0
            running_corrects = 0

            # Iterate over data.
            for inputs, labels in dataloaders[phase]:
                inputs = inputs.to(device)
                labels = labels.to(device)

                # zero the parameter gradients
                optimizer.zero_grad()

                # forward
                # track history if only in train
                with torch.set_grad_enabled(phase == 'train-sample'):
                    outputs = model(inputs)
                    _, preds = torch.max(outputs, 1)
                    loss = criterion(outputs, labels)

                    # backward + optimize only if in training phase
                    if phase == 'train-sample':
                        loss.backward()
                        optimizer.step()

                # statistics
                running_loss += loss.item() * inputs.size(0)
                running_corrects += torch.sum(preds == labels.data)

            epoch_loss = running_loss / dataset_sizes[phase]
            epoch_acc = running_corrects.double() / dataset_sizes[phase]

            print('{} Loss: {:.4f} Acc: {:.4f}'.format(
                phase, epoch_loss, epoch_acc))

            print(epoch_acc)
            # deep copy the model
            if phase == 'val' and epoch_acc > best_acc:
                print('copy to best')
                best_acc = epoch_acc
                best_model_wts = copy.deepcopy(model.state_dict())

        print()

    time_elapsed = time.time() - since
    print('Training complete in {:.0f}m {:.0f}s'.format(
        time_elapsed // 60, time_elapsed % 60))
    print('Best val Acc: {:4f}'.format(best_acc))

    # load best model weights
    model.load_state_dict(best_model_wts)
    return model

# %% [markdown]
# Visualizing the model predictions
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
# Generic function to display predictions for a few images

# %%
def visualize_model(model, num_images=6):
    was_training = model.training
    model.eval()
    images_so_far = 0
    fig = plt.figure()

    with torch.no_grad():
        for i, (inputs, labels) in enumerate(dataloaders['val']):
            inputs = inputs.to(device)
            labels = labels.to(device)

            outputs = model(inputs)
            _, preds = torch.max(outputs, 1)

            for j in range(inputs.size()[0]):
                images_so_far += 1
                ax = plt.subplot(num_images//2, 2, images_so_far)
                ax.axis('off')
                ax.set_title('predicted: {}'.format(class_names[preds[j]]))
                imshow(inputs.cpu().data[j])

                if images_so_far == num_images:
                    model.train(mode=was_training)
                    return
        model.train(mode=was_training)

# %% [markdown]
# Finetuning the convnet
# ----------------------
#
# Load a pretrained model and reset final fully connected layer.

# %%
model_ft = models.resnet18(pretrained=True)
num_ftrs = model_ft.fc.in_features
model_ft.fc = nn.Linear(num_ftrs, 11)

model_ft = model_ft.to(device)

criterion = nn.CrossEntropyLoss()

# Observe that all parameters are being optimized
optimizer_ft = optim.SGD(model_ft.parameters(), lr=0.001, momentum=0.9)

# Decay LR by a factor of 0.1 every 7 epochs
exp_lr_scheduler = lr_scheduler.StepLR(optimizer_ft, step_size=10, gamma=0.5)

# %% [markdown]
# Train and evaluate
# ^^^^^^^^^^^^^^^^^^
#
# It should take around 15-25 min on CPU. On GPU though, it takes less than a
# minute.

# %%
model_ft = train_model(model_ft, criterion, optimizer_ft, exp_lr_scheduler,
                       num_epochs=25)
# Out:
# Epoch 0/24
# ----------
# train-sample Loss: 1.8458 Acc: 0.3891
# tensor(0.3891, device='cuda:0', dtype=torch.float64)
# val Loss: 1.1709 Acc: 0.6207
# tensor(0.6207, device='cuda:0', dtype=torch.float64)
# copy to best
#
# Epoch 1/24
# ----------
# train-sample Loss: 1.4252 Acc: 0.5400
# tensor(0.5400, device='cuda:0', dtype=torch.float64)
# val Loss: 1.3870 Acc: 0.6029
# tensor(0.6029, device='cuda:0', dtype=torch.float64)
#
# Epoch 2/24
# ----------
# train-sample Loss: 1.3773 Acc: 0.5664
# tensor(0.5664, device='cuda:0', dtype=torch.float64)
# val Loss: 1.3374 Acc: 0.6283
# tensor(0.6283, device='cuda:0', dtype=torch.float64)
# copy to best
#
# Epoch 3/24
# ----------
# train-sample Loss: 1.3809 Acc: 0.5627
# tensor(0.5627, device='cuda:0', dtype=torch.float64)
# val Loss: 1.5416 Acc: 0.6227
# tensor(0.6227, device='cuda:0', dtype=torch.float64)
#
# Epoch 4/24
# ----------
# train-sample Loss: 1.2346 Acc: 0.6091
# tensor(0.6091, device='cuda:0', dtype=torch.float64)
# val Loss: 1.1530 Acc: 0.6685
# tensor(0.6685, device='cuda:0', dtype=torch.float64)
# copy to best
#
# Epoch 5/24
# ----------
# train-sample Loss: 1.2403 Acc: 0.6245
# tensor(0.6245, device='cuda:0', dtype=torch.float64)
# val Loss: 1.2696 Acc: 0.6752
# tensor(0.6752, device='cuda:0', dtype=torch.float64)
# copy to best
#
# Epoch 6/24
# ----------
# train-sample Loss: 1.1696 Acc: 0.6327
# tensor(0.6327, device='cuda:0', dtype=torch.float64)
# val Loss: 1.0406 Acc: 0.7041
# tensor(0.7041, device='cuda:0', dtype=torch.float64)
# copy to best
#
# Epoch 7/24
# ----------
# train-sample Loss: 1.1708 Acc: 0.6418
# tensor(0.6418, device='cuda:0', dtype=torch.float64)
# val Loss: 1.0899 Acc: 0.7157
# tensor(0.7157, device='cuda:0', dtype=torch.float64)
# copy to best
#
# Epoch 8/24
# ----------
# train-sample Loss: 1.0884 Acc: 0.6664
# tensor(0.6664, device='cuda:0', dtype=torch.float64)
# val Loss: 1.0614 Acc: 0.7041
# tensor(0.7041, device='cuda:0', dtype=torch.float64)
#
# Epoch 9/24
# ----------
# train-sample Loss: 0.9734 Acc: 0.7000
# tensor(0.7000, device='cuda:0', dtype=torch.float64)
# val Loss: 1.0408 Acc: 0.7227
# tensor(0.7227, device='cuda:0', dtype=torch.float64)
# copy to best
#
# Epoch 10/24
# ----------
# train-sample Loss: 0.8089 Acc: 0.7491
# tensor(0.7491, device='cuda:0', dtype=torch.float64)
# val Loss: 0.8686 Acc: 0.7609
# tensor(0.7609, device='cuda:0', dtype=torch.float64)
# copy to best
#
# Epoch 11/24
# ----------
# train-sample Loss: 0.7472 Acc: 0.7773
# tensor(0.7773, device='cuda:0', dtype=torch.float64)
# val Loss: 0.9788 Acc: 0.7461
# tensor(0.7461, device='cuda:0', dtype=torch.float64)
#
# Epoch 12/24
# ----------
# train-sample Loss: 0.6996 Acc: 0.7882
# tensor(0.7882, device='cuda:0', dtype=torch.float64)
# val Loss: 0.8949 Acc: 0.7615
# tensor(0.7615, device='cuda:0', dtype=torch.float64)
# copy to best
#
# Epoch 13/24
# ----------
# train-sample Loss: 0.6242 Acc: 0.8118
# tensor(0.8118, device='cuda:0', dtype=torch.float64)
# val Loss: 0.9324 Acc: 0.7531
# tensor(0.7531, device='cuda:0', dtype=torch.float64)
#
# Epoch 14/24
# ----------
# train-sample Loss: 0.6289 Acc: 0.7927
# tensor(0.7927, device='cuda:0', dtype=torch.float64)
# val Loss: 0.9197 Acc: 0.7548
# tensor(0.7548, device='cuda:0', dtype=torch.float64)
#
# Epoch 15/24
# ----------
# train-sample Loss: 0.5937 Acc: 0.8136
# tensor(0.8136, device='cuda:0', dtype=torch.float64)
# val Loss: 0.8937 Acc: 0.7650
# tensor(0.7650, device='cuda:0', dtype=torch.float64)
# copy to best
#
# Epoch 16/24
# ----------
# train-sample Loss: 0.6228 Acc: 0.8136
# tensor(0.8136, device='cuda:0', dtype=torch.float64)
# val Loss: 0.9545 Acc: 0.7490
# tensor(0.7490, device='cuda:0', dtype=torch.float64)
#
# Epoch 17/24
# ----------
# train-sample Loss: 0.5959 Acc: 0.8209
# tensor(0.8209, device='cuda:0', dtype=torch.float64)
# val Loss: 0.8818 Acc: 0.7563
# tensor(0.7563, device='cuda:0', dtype=torch.float64)
#
# Epoch 18/24
# ----------
# train-sample Loss: 0.5888 Acc: 0.8091
# tensor(0.8091, device='cuda:0', dtype=torch.float64)
# val Loss: 0.9582 Acc: 0.7504
# tensor(0.7504, device='cuda:0', dtype=torch.float64)
#
# Epoch 19/24
# ----------
# train-sample Loss: 0.5620 Acc: 0.8236
# tensor(0.8236, device='cuda:0', dtype=torch.float64)
# val Loss: 0.9785 Acc: 0.7487
# tensor(0.7487, device='cuda:0', dtype=torch.float64)
#
# Epoch 20/24
# ----------
# train-sample Loss: 0.4678 Acc: 0.8609
# tensor(0.8609, device='cuda:0', dtype=torch.float64)
# val Loss: 0.9369 Acc: 0.7542
# tensor(0.7542, device='cuda:0', dtype=torch.float64)
#
# Epoch 21/24
# ----------
# train-sample Loss: 0.4784 Acc: 0.8464
# tensor(0.8464, device='cuda:0', dtype=torch.float64)
# val Loss: 0.8386 Acc: 0.7714
# tensor(0.7714, device='cuda:0', dtype=torch.float64)
# copy to best
#
# Epoch 22/24
# ----------
# train-sample Loss: 0.3963 Acc: 0.8827
# tensor(0.8827, device='cuda:0', dtype=torch.float64)
# val Loss: 0.8431 Acc: 0.7790
# tensor(0.7790, device='cuda:0', dtype=torch.float64)
# copy to best
#
# Epoch 23/24
# ----------
# train-sample Loss: 0.4732 Acc: 0.8591
# tensor(0.8591, device='cuda:0', dtype=torch.float64)
# val Loss: 0.8760 Acc: 0.7773
# tensor(0.7773, device='cuda:0', dtype=torch.float64)
#
# Epoch 24/24
# ----------
# train-sample Loss: 0.4218 Acc: 0.8691
# tensor(0.8691, device='cuda:0', dtype=torch.float64)
# val Loss: 0.8850 Acc: 0.7741
# tensor(0.7741, device='cuda:0', dtype=torch.float64)
#
# Training complete in 12m 39s
# Best val Acc: 0.779009

# %%
#save entire model
print('==> Saving model..')
torch.save(model_ft, './retrain-all.pt')
print('Finished Saving')

model_ft = torch.load('./retrain-all.pt')
print('Finished Loading')
# Out:
# ==> Saving model..
# Finished Saving
# Finished Loading

# %%
def test(net):
    criterion = nn.CrossEntropyLoss()

    correct = 0
    total = 0
    running_loss = 0.0

    class_correct = list(0. for i in range(11))
    class_total = list(0. for i in range(11))

    with torch.no_grad():
        for data in dataloaders['test']:
            images, labels = data

            images = images.to(device)
            labels = labels.to(device)
        
            outputs = net(images)
            _, predicted = torch.max(outputs, 1)
        
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

            loss = criterion(outputs, labels)
            running_loss += loss.item()

            c = (predicted == labels).squeeze()
            #print(predicted)
            #print(labels.size(0))
            #print(c)
            for i in range(labels.size(0)):
                label = labels[i]
                class_correct[label] += c[i].item()
                class_total[label] += 1

    print('Accuracy of the network on the %d test images: %.2f%%, and loss is: %.3f'
          % (total, 100 * correct / total, running_loss / total))

    class_names = image_datasets['train-sample'].classes
    print(class_names)
    
    for i in range(11):
        print('Accuracy of %5s : %2d %%' % (
            class_names[i], 100 * class_correct[i] / class_total[i]))

# %%
test(model_ft)
# Out:
# Accuracy of the network on the 3347 test images: 80.13%, and loss is: 0.178
# ['0', '1', '10', '2', '3', '4', '5', '6', '7', '8', '9']
# Accuracy of     0 : 54 %
# Accuracy of     1 : 74 %
# Accuracy of    10 : 91 %
# Accuracy of     2 : 68 %
# Accuracy of     3 : 76 %
# Accuracy of     4 : 88 %
# Accuracy of     5 : 82 %
# Accuracy of     6 : 98 %
# Accuracy of     7 : 96 %
# Accuracy of     8 : 85 %
# Accuracy of     9 : 92 %

# %%
visualize_model(model_ft)
# Out:
# Exception ignored in: <function _DataLoaderIter.__del__ at 0x7f3540db8d90>
# Traceback (most recent call last):
#   File "/root/anaconda3/lib/python3.7/site-packages/torch/utils/data/dataloader.py", line 399, in __del__
#     self._shutdown_workers()
#   File "/root/anaconda3/lib/python3.7/site-packages/torch/utils/data/dataloader.py", line 378, in _shutdown_workers
#     self.worker_result_queue.get()
#   File "/root/anaconda3/lib/python3.7/multiprocessing/queues.py", line 354, in get
#     return _ForkingPickler.loads(res)
#   File "/root/anaconda3/lib/python3.7/site-packages/torch/multiprocessing/reductions.py", line 151, in rebuild_storage_fd
#     fd = df.detach()
#   File "/root/anaconda3/lib/python3.7/multiprocessing/resource_sharer.py", line 57, in detach
#     with _resource_sharer.get_connection(self._id) as conn:
#   File "/root/anaconda3/lib/python3.7/multiprocessing/resource_sharer.py", line 87, in get_connection
#     c = Client(address, authkey=process.current_process().authkey)
#   File "/root/anaconda3/lib/python3.7/multiprocessing/connection.py", line 498, in Client
#     answer_challenge(c, authkey)
#   File "/root/anaconda3/lib/python3.7/multiprocessing/connection.py", line 746, in answer_challenge
#     response = connection.recv_bytes(256)        # reject large message
#   File "/root/anaconda3/lib/python3.7/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/root/anaconda3/lib/python3.7/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
#   File "/root/anaconda3/lib/python3.7/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
# ConnectionResetError: [Errno 104] Connection reset by peer

# %% [markdown]
# ConvNet as fixed feature extractor
# ----------------------------------
#
# Here, we need to freeze all the network except the final layer. We need
# to set ``requires_grad == False`` to freeze the parameters so that the
# gradients are not computed in ``backward()``.
#
# You can read more about this in the documentation
# `here <http://pytorch.org/docs/notes/autograd.html#excluding-subgraphs-from-backward>`__.

# %%
model_conv = torchvision.models.resnet18(pretrained=True)
for param in model_conv.parameters():
    param.requires_grad = False

# Parameters of newly constructed modules have requires_grad=True by default
num_ftrs = model_conv.fc.in_features
model_conv.fc = nn.Linear(num_ftrs, 11)

model_conv = model_conv.to(device)

criterion = nn.CrossEntropyLoss()

# Observe that only parameters of final layer are being optimized as
# opoosed to before.
optimizer_conv = optim.SGD(model_conv.fc.parameters(), lr=0.001, momentum=0.9)

# Decay LR by a factor of 0.1 every 7 epochs
exp_lr_scheduler = lr_scheduler.StepLR(optimizer_conv, step_size=7, gamma=0.5)

# %% [markdown]
# Train and evaluate
# ^^^^^^^^^^^^^^^^^^
#
# On CPU this will take about half the time compared to previous scenario.
# This is expected as gradients don't need to be computed for most of the
# network. However, forward does need to be computed.

# %%
model_conv = train_model(model_conv, criterion, optimizer_conv,
                         exp_lr_scheduler, num_epochs=25)
# Out:
# Epoch 0/24
# ----------
# train-sample Loss: 2.0182 Acc: 0.3273
# tensor(0.3273, device='cuda:0', dtype=torch.float64)
# val Loss: 1.3694 Acc: 0.5461
# tensor(0.5461, device='cuda:0', dtype=torch.float64)
# copy to best
#
# Epoch 1/24
# ----------
# train-sample Loss: 1.5624 Acc: 0.4755
# tensor(0.4755, device='cuda:0', dtype=torch.float64)
# val Loss: 1.1600 Acc: 0.6178
# tensor(0.6178, device='cuda:0', dtype=torch.float64)
# copy to best
#
# Epoch 2/24
# ----------
# train-sample Loss: 1.3904 Acc: 0.5545
# tensor(0.5545, device='cuda:0', dtype=torch.float64)
# val Loss: 1.1379 Acc: 0.6297
# tensor(0.6297, device='cuda:0', dtype=torch.float64)
# copy to best
#
# Epoch 3/24
# ----------
# train-sample Loss: 1.3327 Acc: 0.5627
# tensor(0.5627, device='cuda:0', dtype=torch.float64)
# val Loss: 1.1169 Acc: 0.6399
# tensor(0.6399, device='cuda:0', dtype=torch.float64)
# copy to best
#
# Epoch 4/24
# ----------
# train-sample Loss: 1.2434 Acc: 0.5955
# tensor(0.5955, device='cuda:0', dtype=torch.float64)
# val Loss: 1.1581 Acc: 0.6446
# tensor(0.6446, device='cuda:0', dtype=torch.float64)
# copy to best
#
# Epoch 5/24
# ----------
# train-sample Loss: 1.3055 Acc: 0.5782
# tensor(0.5782, device='cuda:0', dtype=torch.float64)
# val Loss: 1.0776 Acc: 0.6723
# tensor(0.6723, device='cuda:0', dtype=torch.float64)
# copy to best
#
# Epoch 6/24
# ----------
# train-sample Loss: 1.2138 Acc: 0.6000
# tensor(0.6000, device='cuda:0', dtype=torch.float64)
# val Loss: 1.1950 Acc: 0.6577
# tensor(0.6577, device='cuda:0', dtype=torch.float64)
#
# Epoch 7/24
# ----------
# train-sample Loss: 1.0549 Acc: 0.6555
# tensor(0.6555, device='cuda:0', dtype=torch.float64)
# val Loss: 0.9560 Acc: 0.7050
# tensor(0.7050, device='cuda:0', dtype=torch.float64)
# copy to best
#
# Epoch 8/24
# ----------
# train-sample Loss: 1.0386 Acc: 0.6636
# tensor(0.6636, device='cuda:0', dtype=torch.float64)
# val Loss: 0.9405 Acc: 0.7012
# tensor(0.7012, device='cuda:0', dtype=torch.float64)
#
# Epoch 9/24
# ----------
# train-sample Loss: 1.0668 Acc: 0.6427
# tensor(0.6427, device='cuda:0', dtype=torch.float64)
# val Loss: 0.9763 Acc: 0.7000
# tensor(0.7000, device='cuda:0', dtype=torch.float64)
#
# Epoch 10/24
# ----------
# train-sample Loss: 1.0582 Acc: 0.6482
# tensor(0.6482, device='cuda:0', dtype=torch.float64)
# val Loss: 0.9802 Acc: 0.6915
# tensor(0.6915, device='cuda:0', dtype=torch.float64)
#
# Epoch 11/24
# ----------
# train-sample Loss: 1.0392 Acc: 0.6636
# tensor(0.6636, device='cuda:0', dtype=torch.float64)
# val Loss: 1.0152 Acc: 0.6875
# tensor(0.6875, device='cuda:0', dtype=torch.float64)
#
# Epoch 12/24
# ----------
# train-sample Loss: 1.0669 Acc: 0.6536
# tensor(0.6536, device='cuda:0', dtype=torch.float64)
# val Loss: 0.9601 Acc: 0.6988
# tensor(0.6988, device='cuda:0', dtype=torch.float64)
#
# Epoch 13/24
# ----------
# train-sample Loss: 1.0411 Acc: 0.6555
# tensor(0.6555, device='cuda:0', dtype=torch.float64)
# val Loss: 0.9676 Acc: 0.7015
# tensor(0.7015, device='cuda:0', dtype=torch.float64)
#
# Epoch 14/24
# ----------
# train-sample Loss: 1.0323 Acc: 0.6709
# tensor(0.6709, device='cuda:0', dtype=torch.float64)
# val Loss: 0.9840 Acc: 0.6939
# tensor(0.6939, device='cuda:0', dtype=torch.float64)
#
# Epoch 15/24
# ----------
# train-sample Loss: 1.0466 Acc: 0.6509
# tensor(0.6509, device='cuda:0', dtype=torch.float64)
# val Loss: 1.0155 Acc: 0.6828
# tensor(0.6828, device='cuda:0', dtype=torch.float64)
#
# Epoch 16/24
# ----------
# train-sample Loss: 1.0051 Acc: 0.6900
# tensor(0.6900, device='cuda:0', dtype=torch.float64)
# val Loss: 0.9478 Acc: 0.7079
# tensor(0.7079, device='cuda:0', dtype=torch.float64)
# copy to best
#
# Epoch 17/24
# ----------
# train-sample Loss: 1.1098 Acc: 0.6418
# tensor(0.6418, device='cuda:0', dtype=torch.float64)
# val Loss: 0.9074 Acc: 0.7149
# tensor(0.7149, device='cuda:0', dtype=torch.float64)
# copy to best
#
# Epoch 18/24
# ----------
# train-sample Loss: 0.9850 Acc: 0.6800
# tensor(0.6800, device='cuda:0', dtype=torch.float64)
# val Loss: 0.9681 Acc: 0.7015
# tensor(0.7015, device='cuda:0', dtype=torch.float64)
#
# Epoch 19/24
# ----------
# train-sample Loss: 1.0489 Acc: 0.6600
# tensor(0.6600, device='cuda:0', dtype=torch.float64)
# val Loss: 0.9372 Acc: 0.7044
# tensor(0.7044, device='cuda:0', dtype=torch.float64)
#
# Epoch 20/24
# ----------
# train-sample Loss: 1.0000 Acc: 0.6791
# tensor(0.6791, device='cuda:0', dtype=torch.float64)
# val Loss: 0.9877 Acc: 0.6910
# tensor(0.6910, device='cuda:0', dtype=torch.float64)
#
# Epoch 21/24
# ----------
# train-sample Loss: 0.9877 Acc: 0.6855
# tensor(0.6855, device='cuda:0', dtype=torch.float64)
# val Loss: 0.9430 Acc: 0.7055
# tensor(0.7055, device='cuda:0', dtype=torch.float64)
#
# Epoch 22/24
# ----------
# train-sample Loss: 1.0461 Acc: 0.6700
# tensor(0.6700, device='cuda:0', dtype=torch.float64)
# val Loss: 0.9611 Acc: 0.7064
# tensor(0.7064, device='cuda:0', dtype=torch.float64)
#
# Epoch 23/24
# ----------
# train-sample Loss: 1.0501 Acc: 0.6682
# tensor(0.6682, device='cuda:0', dtype=torch.float64)
# val Loss: 0.9126 Acc: 0.7093
# tensor(0.7093, device='cuda:0', dtype=torch.float64)
#
# Epoch 24/24
# ----------
# train-sample Loss: 1.0401 Acc: 0.6809
# tensor(0.6809, device='cuda:0', dtype=torch.float64)
# val Loss: 0.9640 Acc: 0.6942
# tensor(0.6942, device='cuda:0', dtype=torch.float64)
#
# Training complete in 12m 37s
# Best val Acc: 0.714869

# %%
#save entire model
print('==> Saving model..')
torch.save(model_conv, './retrain-last.pt')
print('Finished Saving')

model_conv = torch.load('./retrain-last.pt')
print('Finished Loading')
# Out:
# ==> Saving model..
# Finished Saving
# Finished Loading

# %%
test(model_conv)
# Out:
# Accuracy of the network on the 3347 test images: 74.45%, and loss is: 0.196
# ['0', '1', '10', '2', '3', '4', '5', '6', '7', '8', '9']
# Accuracy of     0 : 66 %
# Accuracy of     1 : 75 %
# Accuracy of    10 : 82 %
# Accuracy of     2 : 51 %
# Accuracy of     3 : 65 %
# Accuracy of     4 : 73 %
# Accuracy of     5 : 75 %
# Accuracy of     6 : 95 %
# Accuracy of     7 : 94 %
# Accuracy of     8 : 75 %
# Accuracy of     9 : 93 %

# %%
visualize_model(model_conv)

plt.ioff()
plt.show()
# Out:
# Exception ignored in: <function _DataLoaderIter.__del__ at 0x7f3540db8d90>
# Traceback (most recent call last):
#   File "/root/anaconda3/lib/python3.7/site-packages/torch/utils/data/dataloader.py", line 399, in __del__
#     self._shutdown_workers()
#   File "/root/anaconda3/lib/python3.7/site-packages/torch/utils/data/dataloader.py", line 378, in _shutdown_workers
#     self.worker_result_queue.get()
#   File "/root/anaconda3/lib/python3.7/multiprocessing/queues.py", line 354, in get
#     return _ForkingPickler.loads(res)
#   File "/root/anaconda3/lib/python3.7/site-packages/torch/multiprocessing/reductions.py", line 151, in rebuild_storage_fd
#     fd = df.detach()
#   File "/root/anaconda3/lib/python3.7/multiprocessing/resource_sharer.py", line 57, in detach
#     with _resource_sharer.get_connection(self._id) as conn:
#   File "/root/anaconda3/lib/python3.7/multiprocessing/resource_sharer.py", line 87, in get_connection
#     c = Client(address, authkey=process.current_process().authkey)
#   File "/root/anaconda3/lib/python3.7/multiprocessing/connection.py", line 499, in Client
#     deliver_challenge(c, authkey)
#   File "/root/anaconda3/lib/python3.7/multiprocessing/connection.py", line 729, in deliver_challenge
#     response = connection.recv_bytes(256)        # reject large message
#   File "/root/anaconda3/lib/python3.7/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/root/anaconda3/lib/python3.7/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
#   File "/root/anaconda3/lib/python3.7/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
# ConnectionResetError: [Errno 104] Connection reset by peer

# %%
model_new = models.resnet18(pretrained=False)
num_ftrs = model_new.fc.in_features
model_new.fc = nn.Linear(num_ftrs, 11)

model_new = model_new.to(device)

criterion = nn.CrossEntropyLoss()

# Observe that all parameters are being optimized
optimizer_new = optim.SGD(model_new.parameters(), lr=0.001, momentum=0.9)

# Decay LR by a factor of 0.1 every 7 epochs
exp_lr_scheduler = lr_scheduler.StepLR(optimizer_new, step_size=10, gamma=0.5)

# %%
model_new = train_model(model_new, criterion, optimizer_new, exp_lr_scheduler,
                       num_epochs=25)
# Out:
# Epoch 0/24
# ----------
# train-sample Loss: 2.5105 Acc: 0.1391
# tensor(0.1391, device='cuda:0', dtype=torch.float64)
# val Loss: 2.6071 Acc: 0.1787
# tensor(0.1787, device='cuda:0', dtype=torch.float64)
# copy to best
#
# Epoch 1/24
# ----------
# train-sample Loss: 2.3733 Acc: 0.1782
# tensor(0.1782, device='cuda:0', dtype=torch.float64)
# val Loss: 2.2734 Acc: 0.2169
# tensor(0.2169, device='cuda:0', dtype=torch.float64)
# copy to best
#
# Epoch 2/24
# ----------
# train-sample Loss: 2.3958 Acc: 0.1691
# tensor(0.1691, device='cuda:0', dtype=torch.float64)
# val Loss: 3.0071 Acc: 0.1904
# tensor(0.1904, device='cuda:0', dtype=torch.float64)
#
# Epoch 3/24
# ----------
# train-sample Loss: 2.3645 Acc: 0.1900
# tensor(0.1900, device='cuda:0', dtype=torch.float64)
# val Loss: 2.3953 Acc: 0.2277
# tensor(0.2277, device='cuda:0', dtype=torch.float64)
# copy to best
#
# Epoch 4/24
# ----------
# train-sample Loss: 2.3442 Acc: 0.2036
# tensor(0.2036, device='cuda:0', dtype=torch.float64)
# val Loss: 2.2490 Acc: 0.2423
# tensor(0.2423, device='cuda:0', dtype=torch.float64)
# copy to best
#
# Epoch 5/24
# ----------
# train-sample Loss: 2.2531 Acc: 0.2209
# tensor(0.2209, device='cuda:0', dtype=torch.float64)
# val Loss: 2.2656 Acc: 0.2423
# tensor(0.2423, device='cuda:0', dtype=torch.float64)
#
# Epoch 6/24
# ----------
# train-sample Loss: 2.1966 Acc: 0.2482
# tensor(0.2482, device='cuda:0', dtype=torch.float64)
# val Loss: 2.1854 Acc: 0.2566
# tensor(0.2566, device='cuda:0', dtype=torch.float64)
# copy to best
#
# Epoch 7/24
# ----------
# train-sample Loss: 2.2463 Acc: 0.2318
# tensor(0.2318, device='cuda:0', dtype=torch.float64)
# val Loss: 2.4074 Acc: 0.1924
# tensor(0.1924, device='cuda:0', dtype=torch.float64)
#
# Epoch 8/24
# ----------
# train-sample Loss: 2.2090 Acc: 0.2355
# tensor(0.2355, device='cuda:0', dtype=torch.float64)
# val Loss: 2.0601 Acc: 0.3105
# tensor(0.3105, device='cuda:0', dtype=torch.float64)
# copy to best
#
# Epoch 9/24
# ----------
# train-sample Loss: 2.1852 Acc: 0.2427
# tensor(0.2427, device='cuda:0', dtype=torch.float64)
# val Loss: 2.2319 Acc: 0.2601
# tensor(0.2601, device='cuda:0', dtype=torch.float64)
#
# Epoch 10/24
# ----------
# train-sample Loss: 2.0320 Acc: 0.2727
# tensor(0.2727, device='cuda:0', dtype=torch.float64)
# val Loss: 2.0480 Acc: 0.3347
# tensor(0.3347, device='cuda:0', dtype=torch.float64)
# copy to best
#
# Epoch 11/24
# ----------
# train-sample Loss: 1.9957 Acc: 0.3173
# tensor(0.3173, device='cuda:0', dtype=torch.float64)
# val Loss: 2.1247 Acc: 0.3009
# tensor(0.3009, device='cuda:0', dtype=torch.float64)
#
# Epoch 12/24
# ----------
# train-sample Loss: 1.9638 Acc: 0.3018
# tensor(0.3018, device='cuda:0', dtype=torch.float64)
# val Loss: 2.0122 Acc: 0.3362
# tensor(0.3362, device='cuda:0', dtype=torch.float64)
# copy to best
#
# Epoch 13/24
# ----------
# train-sample Loss: 1.9833 Acc: 0.2955
# tensor(0.2955, device='cuda:0', dtype=torch.float64)
# val Loss: 2.0541 Acc: 0.3420
# tensor(0.3420, device='cuda:0', dtype=torch.float64)
# copy to best
#
# Epoch 14/24
# ----------
# train-sample Loss: 1.9939 Acc: 0.2891
# tensor(0.2891, device='cuda:0', dtype=torch.float64)
# val Loss: 2.0217 Acc: 0.3134
# tensor(0.3134, device='cuda:0', dtype=torch.float64)
#
# Epoch 15/24
# ----------
# train-sample Loss: 1.9912 Acc: 0.3136
# tensor(0.3136, device='cuda:0', dtype=torch.float64)
# val Loss: 1.9357 Acc: 0.3571
# tensor(0.3571, device='cuda:0', dtype=torch.float64)
# copy to best
#
# Epoch 16/24
# ----------
# train-sample Loss: 1.9896 Acc: 0.3045
# tensor(0.3045, device='cuda:0', dtype=torch.float64)
# val Loss: 1.9678 Acc: 0.3469
# tensor(0.3469, device='cuda:0', dtype=torch.float64)
#
# Epoch 17/24
# ----------
# train-sample Loss: 1.9256 Acc: 0.3300
# tensor(0.3300, device='cuda:0', dtype=torch.float64)
# val Loss: 2.1050 Acc: 0.3464
# tensor(0.3464, device='cuda:0', dtype=torch.float64)
#
# Epoch 18/24
# ----------
# train-sample Loss: 1.9567 Acc: 0.3118
# tensor(0.3118, device='cuda:0', dtype=torch.float64)
# val Loss: 1.9878 Acc: 0.3239
# tensor(0.3239, device='cuda:0', dtype=torch.float64)
#
# Epoch 19/24
# ----------
# train-sample Loss: 1.9068 Acc: 0.3400
# tensor(0.3400, device='cuda:0', dtype=torch.float64)
# val Loss: 2.0446 Acc: 0.3598
# tensor(0.3598, device='cuda:0', dtype=torch.float64)
# copy to best
#
# Epoch 20/24
# ----------
# train-sample Loss: 1.8344 Acc: 0.3409
# tensor(0.3409, device='cuda:0', dtype=torch.float64)
# val Loss: 1.9078 Acc: 0.3729
# tensor(0.3729, device='cuda:0', dtype=torch.float64)
# copy to best
#
# Epoch 21/24
# ----------
# train-sample Loss: 1.8056 Acc: 0.3745
# tensor(0.3745, device='cuda:0', dtype=torch.float64)
# val Loss: 1.8755 Acc: 0.3959
# tensor(0.3959, device='cuda:0', dtype=torch.float64)
# copy to best
#
# Epoch 22/24
# ----------
# train-sample Loss: 1.8189 Acc: 0.3700
# tensor(0.3700, device='cuda:0', dtype=torch.float64)
# val Loss: 1.7899 Acc: 0.4076
# tensor(0.4076, device='cuda:0', dtype=torch.float64)
# copy to best
#
# Epoch 23/24
# ----------
# train-sample Loss: 1.8140 Acc: 0.3873
# tensor(0.3873, device='cuda:0', dtype=torch.float64)
# val Loss: 1.9182 Acc: 0.3933
# tensor(0.3933, device='cuda:0', dtype=torch.float64)
#
# Epoch 24/24
# ----------
# train-sample Loss: 1.8039 Acc: 0.3782
# tensor(0.3782, device='cuda:0', dtype=torch.float64)
# val Loss: 1.7997 Acc: 0.4079
# tensor(0.4079, device='cuda:0', dtype=torch.float64)
# copy to best
#
# Training complete in 12m 37s
# Best val Acc: 0.407872

# %%
#save entire model
print('==> Saving model..')
torch.save(model_new, './new-train.pt')
print('Finished Saving')

model_new = torch.load('./new-train.pt')
print('Finished Loading')
# Out:
# ==> Saving model..
# Finished Saving
# Finished Loading

# %%
test(model_new)
# Out:
# Accuracy of the network on the 3347 test images: 41.29%, and loss is: 0.447
# ['0', '1', '10', '2', '3', '4', '5', '6', '7', '8', '9']
# Accuracy of     0 : 15 %
# Accuracy of     1 : 10 %
# Accuracy of    10 : 67 %
# Accuracy of     2 : 51 %
# Accuracy of     3 : 14 %
# Accuracy of     4 : 42 %
# Accuracy of     5 : 39 %
# Accuracy of     6 : 66 %
# Accuracy of     7 : 37 %
# Accuracy of     8 : 56 %
# Accuracy of     9 : 51 %

# %%
model_new = train_model(model_new, criterion, optimizer_new, exp_lr_scheduler,
                       num_epochs=100)
# Out:
# Epoch 0/99
# ----------
# train-sample Loss: 1.7024 Acc: 0.4300
# tensor(0.4300, device='cuda:0', dtype=torch.float64)
# val Loss: 1.8074 Acc: 0.4052
# tensor(0.4052, device='cuda:0', dtype=torch.float64)
# copy to best
#
# Epoch 1/99
# ----------
# train-sample Loss: 1.6982 Acc: 0.4200
# tensor(0.4200, device='cuda:0', dtype=torch.float64)
# val Loss: 1.8343 Acc: 0.3983
# tensor(0.3983, device='cuda:0', dtype=torch.float64)
#
# Epoch 2/99
# ----------
# train-sample Loss: 1.7054 Acc: 0.4027
# tensor(0.4027, device='cuda:0', dtype=torch.float64)
# val Loss: 1.8476 Acc: 0.4029
# tensor(0.4029, device='cuda:0', dtype=torch.float64)
#
# Epoch 3/99
# ----------
# train-sample Loss: 1.7255 Acc: 0.4273
# tensor(0.4273, device='cuda:0', dtype=torch.float64)
# val Loss: 1.8555 Acc: 0.3971
# tensor(0.3971, device='cuda:0', dtype=torch.float64)
#
# Epoch 4/99
# ----------
# train-sample Loss: 1.7170 Acc: 0.4155
# tensor(0.4155, device='cuda:0', dtype=torch.float64)
# val Loss: 1.8432 Acc: 0.4041
# tensor(0.4041, device='cuda:0', dtype=torch.float64)
#
# Epoch 5/99
# ----------
# train-sample Loss: 1.6957 Acc: 0.4300
# tensor(0.4300, device='cuda:0', dtype=torch.float64)
# val Loss: 1.7861 Acc: 0.4125
# tensor(0.4125, device='cuda:0', dtype=torch.float64)
# copy to best
#
# Epoch 6/99
# ----------
# train-sample Loss: 1.7220 Acc: 0.4200
# tensor(0.4200, device='cuda:0', dtype=torch.float64)
# val Loss: 1.7954 Acc: 0.4038
# tensor(0.4038, device='cuda:0', dtype=torch.float64)
#
# Epoch 7/99
# ----------
# train-sample Loss: 1.7400 Acc: 0.4127
# tensor(0.4127, device='cuda:0', dtype=torch.float64)
# val Loss: 1.8411 Acc: 0.4020
# tensor(0.4020, device='cuda:0', dtype=torch.float64)
#
# Epoch 8/99
# ----------
# train-sample Loss: 1.7106 Acc: 0.4127
# tensor(0.4127, device='cuda:0', dtype=torch.float64)
# val Loss: 1.8431 Acc: 0.3968
# tensor(0.3968, device='cuda:0', dtype=torch.float64)
#
# Epoch 9/99
# ----------
# train-sample Loss: 1.7413 Acc: 0.3955
# tensor(0.3955, device='cuda:0', dtype=torch.float64)
# val Loss: 1.8497 Acc: 0.3956
# tensor(0.3956, device='cuda:0', dtype=torch.float64)
#
# Epoch 10/99
# ----------
# train-sample Loss: 1.7129 Acc: 0.4127
# tensor(0.4127, device='cuda:0', dtype=torch.float64)
# val Loss: 1.8245 Acc: 0.4009
# tensor(0.4009, device='cuda:0', dtype=torch.float64)
#
# Epoch 11/99
# ----------
# train-sample Loss: 1.7665 Acc: 0.3900
# tensor(0.3900, device='cuda:0', dtype=torch.float64)
# val Loss: 1.8509 Acc: 0.3918
# tensor(0.3918, device='cuda:0', dtype=torch.float64)
#
# Epoch 12/99
# ----------
# train-sample Loss: 1.7294 Acc: 0.4018
# tensor(0.4018, device='cuda:0', dtype=torch.float64)
# val Loss: 1.7857 Acc: 0.4152
# tensor(0.4152, device='cuda:0', dtype=torch.float64)
# copy to best
#
# Epoch 13/99
# ----------
# train-sample Loss: 1.7149 Acc: 0.4082
# tensor(0.4082, device='cuda:0', dtype=torch.float64)
# val Loss: 1.8014 Acc: 0.4111
# tensor(0.4111, device='cuda:0', dtype=torch.float64)
#
# Epoch 14/99
# ----------
# train-sample Loss: 1.7532 Acc: 0.3918
# tensor(0.3918, device='cuda:0', dtype=torch.float64)
# val Loss: 1.8285 Acc: 0.4041
# tensor(0.4041, device='cuda:0', dtype=torch.float64)
#
# Epoch 15/99
# ----------
# train-sample Loss: 1.7180 Acc: 0.4082
# tensor(0.4082, device='cuda:0', dtype=torch.float64)
# val Loss: 1.8366 Acc: 0.4067
# tensor(0.4067, device='cuda:0', dtype=torch.float64)
#
# Epoch 16/99
# ----------
# train-sample Loss: 1.7657 Acc: 0.4000
# tensor(0.4000, device='cuda:0', dtype=torch.float64)
# val Loss: 1.7945 Acc: 0.4044
# tensor(0.4044, device='cuda:0', dtype=torch.float64)
#
# Epoch 17/99
# ----------
# train-sample Loss: 1.7121 Acc: 0.4118
# tensor(0.4118, device='cuda:0', dtype=torch.float64)
# val Loss: 1.7987 Acc: 0.4134
# tensor(0.4134, device='cuda:0', dtype=torch.float64)
#
# Epoch 18/99
# ----------
# train-sample Loss: 1.6905 Acc: 0.4255
# tensor(0.4255, device='cuda:0', dtype=torch.float64)
# val Loss: 1.8059 Acc: 0.4026
# tensor(0.4026, device='cuda:0', dtype=torch.float64)
#
# Epoch 19/99
# ----------
# train-sample Loss: 1.7200 Acc: 0.4082
# tensor(0.4082, device='cuda:0', dtype=torch.float64)
# val Loss: 1.8064 Acc: 0.4000
# tensor(0.4000, device='cuda:0', dtype=torch.float64)
#
# Epoch 20/99
# ----------
# train-sample Loss: 1.7011 Acc: 0.4118
# tensor(0.4118, device='cuda:0', dtype=torch.float64)
# val Loss: 1.8370 Acc: 0.3904
# tensor(0.3904, device='cuda:0', dtype=torch.float64)
#
# Epoch 21/99
# ----------
# train-sample Loss: 1.7307 Acc: 0.4236
# tensor(0.4236, device='cuda:0', dtype=torch.float64)
# val Loss: 1.8843 Acc: 0.3942
# tensor(0.3942, device='cuda:0', dtype=torch.float64)
#
# Epoch 22/99
# ----------
# train-sample Loss: 1.7058 Acc: 0.4309
# tensor(0.4309, device='cuda:0', dtype=torch.float64)
# val Loss: 1.8354 Acc: 0.3980
# tensor(0.3980, device='cuda:0', dtype=torch.float64)
#
# Epoch 23/99
# ----------
# train-sample Loss: 1.7187 Acc: 0.4136
# tensor(0.4136, device='cuda:0', dtype=torch.float64)
# val Loss: 1.8706 Acc: 0.3980
# tensor(0.3980, device='cuda:0', dtype=torch.float64)
#
# Epoch 24/99
# ----------
# train-sample Loss: 1.6743 Acc: 0.4509
# tensor(0.4509, device='cuda:0', dtype=torch.float64)
# val Loss: 1.8418 Acc: 0.3953
# tensor(0.3953, device='cuda:0', dtype=torch.float64)
#
# Epoch 25/99
# ----------
# train-sample Loss: 1.7219 Acc: 0.4173
# tensor(0.4173, device='cuda:0', dtype=torch.float64)
# val Loss: 1.8319 Acc: 0.3991
# tensor(0.3991, device='cuda:0', dtype=torch.float64)
#
# Epoch 26/99
# ----------
# train-sample Loss: 1.7545 Acc: 0.3964
# tensor(0.3964, device='cuda:0', dtype=torch.float64)
# val Loss: 1.8399 Acc: 0.4026
# tensor(0.4026, device='cuda:0', dtype=torch.float64)
#
# Epoch 27/99
# ----------
# train-sample Loss: 1.7461 Acc: 0.4000
# tensor(0.4000, device='cuda:0', dtype=torch.float64)
# val Loss: 1.8291 Acc: 0.4055
# tensor(0.4055, device='cuda:0', dtype=torch.float64)
#
# Epoch 28/99
# ----------
# train-sample Loss: 1.7523 Acc: 0.3936
# tensor(0.3936, device='cuda:0', dtype=torch.float64)
# val Loss: 1.8095 Acc: 0.4032
# tensor(0.4032, device='cuda:0', dtype=torch.float64)
#
# Epoch 29/99
# ----------
# train-sample Loss: 1.7109 Acc: 0.4191
# tensor(0.4191, device='cuda:0', dtype=torch.float64)
# val Loss: 1.9394 Acc: 0.3735
# tensor(0.3735, device='cuda:0', dtype=torch.float64)
#
# Epoch 30/99
# ----------
# train-sample Loss: 1.7149 Acc: 0.4127
# tensor(0.4127, device='cuda:0', dtype=torch.float64)
# val Loss: 1.8593 Acc: 0.3936
# tensor(0.3936, device='cuda:0', dtype=torch.float64)
#
# Epoch 31/99
# ----------
# train-sample Loss: 1.6830 Acc: 0.4200
# tensor(0.4200, device='cuda:0', dtype=torch.float64)
# val Loss: 1.7898 Acc: 0.4120
# tensor(0.4120, device='cuda:0', dtype=torch.float64)
#
# Epoch 32/99
# ----------
# train-sample Loss: 1.7486 Acc: 0.4055
# tensor(0.4055, device='cuda:0', dtype=torch.float64)
# val Loss: 1.8786 Acc: 0.3959
# tensor(0.3959, device='cuda:0', dtype=torch.float64)
#
# Epoch 33/99
# ----------
# train-sample Loss: 1.7263 Acc: 0.4073
# tensor(0.4073, device='cuda:0', dtype=torch.float64)
# val Loss: 1.8771 Acc: 0.3927
# tensor(0.3927, device='cuda:0', dtype=torch.float64)
#
# Epoch 34/99
# ----------
# train-sample Loss: 1.6984 Acc: 0.4236
# tensor(0.4236, device='cuda:0', dtype=torch.float64)
# val Loss: 1.7697 Acc: 0.4146
# tensor(0.4146, device='cuda:0', dtype=torch.float64)
#
# Epoch 35/99
# ----------
# train-sample Loss: 1.7407 Acc: 0.4109
# tensor(0.4109, device='cuda:0', dtype=torch.float64)
# val Loss: 1.7745 Acc: 0.4146
# tensor(0.4146, device='cuda:0', dtype=torch.float64)
#
# Epoch 36/99
# ----------
# train-sample Loss: 1.7363 Acc: 0.4327
# tensor(0.4327, device='cuda:0', dtype=torch.float64)
# val Loss: 1.7925 Acc: 0.4108
# tensor(0.4108, device='cuda:0', dtype=torch.float64)
#
# Epoch 37/99
# ----------
# train-sample Loss: 1.7086 Acc: 0.4273
# tensor(0.4273, device='cuda:0', dtype=torch.float64)
# val Loss: 1.8223 Acc: 0.3915
# tensor(0.3915, device='cuda:0', dtype=torch.float64)
#
# Epoch 38/99
# ----------
# train-sample Loss: 1.7028 Acc: 0.4136
# tensor(0.4136, device='cuda:0', dtype=torch.float64)
# val Loss: 1.9008 Acc: 0.3860
# tensor(0.3860, device='cuda:0', dtype=torch.float64)
#
# Epoch 39/99
# ----------
# train-sample Loss: 1.7311 Acc: 0.3964
# tensor(0.3964, device='cuda:0', dtype=torch.float64)
# val Loss: 1.7923 Acc: 0.4111
# tensor(0.4111, device='cuda:0', dtype=torch.float64)
#
# Epoch 40/99
# ----------
# train-sample Loss: 1.7088 Acc: 0.4045
# tensor(0.4045, device='cuda:0', dtype=torch.float64)
# val Loss: 1.7898 Acc: 0.4099
# tensor(0.4099, device='cuda:0', dtype=torch.float64)
#
# Epoch 41/99
# ----------
# train-sample Loss: 1.7060 Acc: 0.4345
# tensor(0.4345, device='cuda:0', dtype=torch.float64)
# val Loss: 1.7682 Acc: 0.4122
# tensor(0.4122, device='cuda:0', dtype=torch.float64)
#
# Epoch 42/99
# ----------
# train-sample Loss: 1.7084 Acc: 0.4400
# tensor(0.4400, device='cuda:0', dtype=torch.float64)
# val Loss: 1.7958 Acc: 0.4114
# tensor(0.4114, device='cuda:0', dtype=torch.float64)
#
# Epoch 43/99
# ----------
# train-sample Loss: 1.6793 Acc: 0.4355
# tensor(0.4355, device='cuda:0', dtype=torch.float64)
# val Loss: 1.7828 Acc: 0.4178
# tensor(0.4178, device='cuda:0', dtype=torch.float64)
# copy to best
#
# Epoch 44/99
# ----------
# train-sample Loss: 1.7223 Acc: 0.4109
# tensor(0.4109, device='cuda:0', dtype=torch.float64)
# val Loss: 1.8503 Acc: 0.3968
# tensor(0.3968, device='cuda:0', dtype=torch.float64)
#
# Epoch 45/99
# ----------
# train-sample Loss: 1.7489 Acc: 0.4082
# tensor(0.4082, device='cuda:0', dtype=torch.float64)
# val Loss: 1.8401 Acc: 0.3904
# tensor(0.3904, device='cuda:0', dtype=torch.float64)
#
# Epoch 46/99
# ----------
# train-sample Loss: 1.7428 Acc: 0.4018
# tensor(0.4018, device='cuda:0', dtype=torch.float64)
# val Loss: 1.9022 Acc: 0.3988
# tensor(0.3988, device='cuda:0', dtype=torch.float64)
#
# Epoch 47/99
# ----------
# train-sample Loss: 1.7289 Acc: 0.4164
# tensor(0.4164, device='cuda:0', dtype=torch.float64)
# val Loss: 1.8207 Acc: 0.4009
# tensor(0.4009, device='cuda:0', dtype=torch.float64)
#
# Epoch 48/99
# ----------
# train-sample Loss: 1.7125 Acc: 0.4245
# tensor(0.4245, device='cuda:0', dtype=torch.float64)
# val Loss: 1.8289 Acc: 0.4073
# tensor(0.4073, device='cuda:0', dtype=torch.float64)
#
# Epoch 49/99
# ----------
# train-sample Loss: 1.7169 Acc: 0.4400
# tensor(0.4400, device='cuda:0', dtype=torch.float64)
# val Loss: 1.8101 Acc: 0.4020
# tensor(0.4020, device='cuda:0', dtype=torch.float64)
#
# Epoch 50/99
# ----------
# train-sample Loss: 1.6705 Acc: 0.4236
# tensor(0.4236, device='cuda:0', dtype=torch.float64)
# val Loss: 1.7699 Acc: 0.4224
# tensor(0.4224, device='cuda:0', dtype=torch.float64)
# copy to best
#
# Epoch 51/99
# ----------
# train-sample Loss: 1.7414 Acc: 0.4091
# tensor(0.4091, device='cuda:0', dtype=torch.float64)
# val Loss: 1.8314 Acc: 0.4026
# tensor(0.4026, device='cuda:0', dtype=torch.float64)
#
# Epoch 52/99
# ----------
# train-sample Loss: 1.7021 Acc: 0.4273
# tensor(0.4273, device='cuda:0', dtype=torch.float64)
# val Loss: 1.8016 Acc: 0.4079
# tensor(0.4079, device='cuda:0', dtype=torch.float64)
#
# Epoch 53/99
# ----------
# train-sample Loss: 1.7435 Acc: 0.3936
# tensor(0.3936, device='cuda:0', dtype=torch.float64)
# val Loss: 1.8755 Acc: 0.3901
# tensor(0.3901, device='cuda:0', dtype=torch.float64)
#
# Epoch 54/99
# ----------
# train-sample Loss: 1.6923 Acc: 0.4236
# tensor(0.4236, device='cuda:0', dtype=torch.float64)
# val Loss: 1.7728 Acc: 0.4143
# tensor(0.4143, device='cuda:0', dtype=torch.float64)
#
# Epoch 55/99
# ----------
# train-sample Loss: 1.6896 Acc: 0.4436
# tensor(0.4436, device='cuda:0', dtype=torch.float64)
# val Loss: 1.8184 Acc: 0.4076
# tensor(0.4076, device='cuda:0', dtype=torch.float64)
#
# Epoch 56/99
# ----------
# train-sample Loss: 1.7319 Acc: 0.4109
# tensor(0.4109, device='cuda:0', dtype=torch.float64)
# val Loss: 1.8322 Acc: 0.3953
# tensor(0.3953, device='cuda:0', dtype=torch.float64)
#
# Epoch 57/99
# ----------
# train-sample Loss: 1.7302 Acc: 0.4109
# tensor(0.4109, device='cuda:0', dtype=torch.float64)
# val Loss: 1.9190 Acc: 0.3784
# tensor(0.3784, device='cuda:0', dtype=torch.float64)
#
# Epoch 58/99
# ----------
# train-sample Loss: 1.7688 Acc: 0.3891
# tensor(0.3891, device='cuda:0', dtype=torch.float64)
# val Loss: 1.8099 Acc: 0.4093
# tensor(0.4093, device='cuda:0', dtype=torch.float64)
#
# Epoch 59/99
# ----------
# train-sample Loss: 1.7013 Acc: 0.4155
# tensor(0.4155, device='cuda:0', dtype=torch.float64)
# val Loss: 1.7471 Acc: 0.4257
# tensor(0.4257, device='cuda:0', dtype=torch.float64)
# copy to best
#
# Epoch 60/99
# ----------
# train-sample Loss: 1.7585 Acc: 0.4009
# tensor(0.4009, device='cuda:0', dtype=torch.float64)
# val Loss: 1.7992 Acc: 0.4160
# tensor(0.4160, device='cuda:0', dtype=torch.float64)
#
# Epoch 61/99
# ----------
# train-sample Loss: 1.7292 Acc: 0.4136
# tensor(0.4136, device='cuda:0', dtype=torch.float64)
# val Loss: 1.8797 Acc: 0.3845
# tensor(0.3845, device='cuda:0', dtype=torch.float64)
#
# Epoch 62/99
# ----------
# train-sample Loss: 1.7264 Acc: 0.4236
# tensor(0.4236, device='cuda:0', dtype=torch.float64)
# val Loss: 1.8604 Acc: 0.3994
# tensor(0.3994, device='cuda:0', dtype=torch.float64)
#
# Epoch 63/99
# ----------
# train-sample Loss: 1.7334 Acc: 0.4082
# tensor(0.4082, device='cuda:0', dtype=torch.float64)
# val Loss: 1.8308 Acc: 0.3985
# tensor(0.3985, device='cuda:0', dtype=torch.float64)
#
# Epoch 64/99
# ----------
# train-sample Loss: 1.7520 Acc: 0.3945
# tensor(0.3945, device='cuda:0', dtype=torch.float64)
# val Loss: 1.9066 Acc: 0.3813
# tensor(0.3813, device='cuda:0', dtype=torch.float64)
#
# Epoch 65/99
# ----------
# train-sample Loss: 1.7658 Acc: 0.4073
# tensor(0.4073, device='cuda:0', dtype=torch.float64)
# val Loss: 1.8145 Acc: 0.4076
# tensor(0.4076, device='cuda:0', dtype=torch.float64)
#
# Epoch 66/99
# ----------
# train-sample Loss: 1.7530 Acc: 0.3873
# tensor(0.3873, device='cuda:0', dtype=torch.float64)
# val Loss: 1.7917 Acc: 0.4099
# tensor(0.4099, device='cuda:0', dtype=torch.float64)
#
# Epoch 67/99
# ----------
# train-sample Loss: 1.7368 Acc: 0.4118
# tensor(0.4118, device='cuda:0', dtype=torch.float64)
# val Loss: 1.8122 Acc: 0.4041
# tensor(0.4041, device='cuda:0', dtype=torch.float64)
#
# Epoch 68/99
# ----------
# train-sample Loss: 1.7213 Acc: 0.4127
# tensor(0.4127, device='cuda:0', dtype=torch.float64)
# val Loss: 1.8072 Acc: 0.4073
# tensor(0.4073, device='cuda:0', dtype=torch.float64)
#
# Epoch 69/99
# ----------
# train-sample Loss: 1.7434 Acc: 0.4009
# tensor(0.4009, device='cuda:0', dtype=torch.float64)
# val Loss: 1.7994 Acc: 0.4096
# tensor(0.4096, device='cuda:0', dtype=torch.float64)
#
# Epoch 70/99
# ----------
# train-sample Loss: 1.7497 Acc: 0.4091
# tensor(0.4091, device='cuda:0', dtype=torch.float64)
# val Loss: 1.7852 Acc: 0.4125
# tensor(0.4125, device='cuda:0', dtype=torch.float64)
#
# Epoch 71/99
# ----------
# train-sample Loss: 1.7527 Acc: 0.4055
# tensor(0.4055, device='cuda:0', dtype=torch.float64)
# val Loss: 1.8438 Acc: 0.3994
# tensor(0.3994, device='cuda:0', dtype=torch.float64)
#
# Epoch 72/99
# ----------
# train-sample Loss: 1.7244 Acc: 0.4127
# tensor(0.4127, device='cuda:0', dtype=torch.float64)
# val Loss: 1.8393 Acc: 0.3983
# tensor(0.3983, device='cuda:0', dtype=torch.float64)
#
# Epoch 73/99
# ----------
# train-sample Loss: 1.7386 Acc: 0.4000
# tensor(0.4000, device='cuda:0', dtype=torch.float64)
# val Loss: 1.8569 Acc: 0.3971
# tensor(0.3971, device='cuda:0', dtype=torch.float64)
#
# Epoch 74/99
# ----------
# train-sample Loss: 1.7280 Acc: 0.4136
# tensor(0.4136, device='cuda:0', dtype=torch.float64)
# val Loss: 1.8844 Acc: 0.3904
# tensor(0.3904, device='cuda:0', dtype=torch.float64)
#
# Epoch 75/99
# ----------
# train-sample Loss: 1.7189 Acc: 0.4018
# tensor(0.4018, device='cuda:0', dtype=torch.float64)
# val Loss: 1.7799 Acc: 0.4140
# tensor(0.4140, device='cuda:0', dtype=torch.float64)
#
# Epoch 76/99
# ----------
# train-sample Loss: 1.7111 Acc: 0.4209
# tensor(0.4209, device='cuda:0', dtype=torch.float64)
# val Loss: 1.8095 Acc: 0.4073
# tensor(0.4073, device='cuda:0', dtype=torch.float64)
#
# Epoch 77/99
# ----------
# train-sample Loss: 1.7352 Acc: 0.4100
# tensor(0.4100, device='cuda:0', dtype=torch.float64)
# val Loss: 1.8222 Acc: 0.4026
# tensor(0.4026, device='cuda:0', dtype=torch.float64)
#
# Epoch 78/99
# ----------
# train-sample Loss: 1.7045 Acc: 0.4273
# tensor(0.4273, device='cuda:0', dtype=torch.float64)
# val Loss: 1.8357 Acc: 0.4102
# tensor(0.4102, device='cuda:0', dtype=torch.float64)
#
# Epoch 79/99
# ----------
# train-sample Loss: 1.7173 Acc: 0.3973
# tensor(0.3973, device='cuda:0', dtype=torch.float64)
# val Loss: 1.7601 Acc: 0.4207
# tensor(0.4207, device='cuda:0', dtype=torch.float64)
#
# Epoch 80/99
# ----------
# train-sample Loss: 1.7181 Acc: 0.4082
# tensor(0.4082, device='cuda:0', dtype=torch.float64)
# val Loss: 1.8428 Acc: 0.4000
# tensor(0.4000, device='cuda:0', dtype=torch.float64)
#
# Epoch 81/99
# ----------
# train-sample Loss: 1.6988 Acc: 0.4345
# tensor(0.4345, device='cuda:0', dtype=torch.float64)
# val Loss: 1.8350 Acc: 0.3983
# tensor(0.3983, device='cuda:0', dtype=torch.float64)
#
# Epoch 82/99
# ----------
# train-sample Loss: 1.7193 Acc: 0.4109
# tensor(0.4109, device='cuda:0', dtype=torch.float64)
# val Loss: 1.8056 Acc: 0.4073
# tensor(0.4073, device='cuda:0', dtype=torch.float64)
#
# Epoch 83/99
# ----------
# train-sample Loss: 1.7205 Acc: 0.4355
# tensor(0.4355, device='cuda:0', dtype=torch.float64)
# val Loss: 1.7541 Acc: 0.4143
# tensor(0.4143, device='cuda:0', dtype=torch.float64)
#
# Epoch 84/99
# ----------
# train-sample Loss: 1.7438 Acc: 0.4109
# tensor(0.4109, device='cuda:0', dtype=torch.float64)
# val Loss: 1.7949 Acc: 0.4149
# tensor(0.4149, device='cuda:0', dtype=torch.float64)
#
# Epoch 85/99
# ----------
# train-sample Loss: 1.7075 Acc: 0.4200
# tensor(0.4200, device='cuda:0', dtype=torch.float64)
# val Loss: 1.8158 Acc: 0.4082
# tensor(0.4082, device='cuda:0', dtype=torch.float64)
#
# Epoch 86/99
# ----------
# train-sample Loss: 1.7076 Acc: 0.4191
# tensor(0.4191, device='cuda:0', dtype=torch.float64)
# val Loss: 1.7437 Acc: 0.4192
# tensor(0.4192, device='cuda:0', dtype=torch.float64)
#
# Epoch 87/99
# ----------
# train-sample Loss: 1.7482 Acc: 0.4027
# tensor(0.4027, device='cuda:0', dtype=torch.float64)
# val Loss: 1.8775 Acc: 0.3915
# tensor(0.3915, device='cuda:0', dtype=torch.float64)
#
# Epoch 88/99
# ----------
# train-sample Loss: 1.7707 Acc: 0.4009
# tensor(0.4009, device='cuda:0', dtype=torch.float64)
# val Loss: 1.8108 Acc: 0.4044
# tensor(0.4044, device='cuda:0', dtype=torch.float64)
#
# Epoch 89/99
# ----------
# train-sample Loss: 1.7522 Acc: 0.4127
# tensor(0.4127, device='cuda:0', dtype=torch.float64)
# val Loss: 1.7506 Acc: 0.4187
# tensor(0.4187, device='cuda:0', dtype=torch.float64)
#
# Epoch 90/99
# ----------
# train-sample Loss: 1.7384 Acc: 0.3936
# tensor(0.3936, device='cuda:0', dtype=torch.float64)
# val Loss: 1.8221 Acc: 0.4061
# tensor(0.4061, device='cuda:0', dtype=torch.float64)
#
# Epoch 91/99
# ----------
# train-sample Loss: 1.7407 Acc: 0.4091
# tensor(0.4091, device='cuda:0', dtype=torch.float64)
# val Loss: 1.8396 Acc: 0.4029
# tensor(0.4029, device='cuda:0', dtype=torch.float64)
#
# Epoch 92/99
# ----------
# train-sample Loss: 1.7297 Acc: 0.4182
# tensor(0.4182, device='cuda:0', dtype=torch.float64)
# val Loss: 1.8336 Acc: 0.3936
# tensor(0.3936, device='cuda:0', dtype=torch.float64)
#
# Epoch 93/99
# ----------
# train-sample Loss: 1.7065 Acc: 0.4355
# tensor(0.4355, device='cuda:0', dtype=torch.float64)
# val Loss: 1.8195 Acc: 0.4047
# tensor(0.4047, device='cuda:0', dtype=torch.float64)
#
# Epoch 94/99
# ----------
# train-sample Loss: 1.7838 Acc: 0.4164
# tensor(0.4164, device='cuda:0', dtype=torch.float64)
# val Loss: 1.7742 Acc: 0.4152
# tensor(0.4152, device='cuda:0', dtype=torch.float64)
#
# Epoch 95/99
# ----------
# train-sample Loss: 1.7291 Acc: 0.4173
# tensor(0.4173, device='cuda:0', dtype=torch.float64)
# val Loss: 1.8034 Acc: 0.4090
# tensor(0.4090, device='cuda:0', dtype=torch.float64)
#
# Epoch 96/99
# ----------
# train-sample Loss: 1.7218 Acc: 0.4209
# tensor(0.4209, device='cuda:0', dtype=torch.float64)
# val Loss: 1.8639 Acc: 0.3988
# tensor(0.3988, device='cuda:0', dtype=torch.float64)
#
# Epoch 97/99
# ----------
# train-sample Loss: 1.7027 Acc: 0.4318
# tensor(0.4318, device='cuda:0', dtype=torch.float64)
# val Loss: 1.8418 Acc: 0.3985
# tensor(0.3985, device='cuda:0', dtype=torch.float64)
#
# Epoch 98/99
# ----------
# train-sample Loss: 1.7210 Acc: 0.4227
# tensor(0.4227, device='cuda:0', dtype=torch.float64)
# val Loss: 1.7777 Acc: 0.4149
# tensor(0.4149, device='cuda:0', dtype=torch.float64)
#
# Epoch 99/99
# ----------
# train-sample Loss: 1.7237 Acc: 0.4127
# tensor(0.4127, device='cuda:0', dtype=torch.float64)
# val Loss: 1.8285 Acc: 0.4026
# tensor(0.4026, device='cuda:0', dtype=torch.float64)
#
# Training complete in 50m 14s
# Best val Acc: 0.425656

# %%
#save entire model
print('==> Saving model..')
torch.save(model_new, './new-train-100.pt')
print('Finished Saving')

model_new = torch.load('./new-train-100.pt')
print('Finished Loading')
# Out:
# ==> Saving model..
# Finished Saving
# Finished Loading

# %%
test(model_new)
# Out:
# Accuracy of the network on the 3347 test images: 42.34%, and loss is: 0.433
# ['0', '1', '10', '2', '3', '4', '5', '6', '7', '8', '9']
# Accuracy of     0 : 14 %
# Accuracy of     1 : 13 %
# Accuracy of    10 : 79 %
# Accuracy of     2 : 36 %
# Accuracy of     3 : 11 %
# Accuracy of     4 : 47 %
# Accuracy of     5 : 44 %
# Accuracy of     6 : 63 %
# Accuracy of     7 : 42 %
# Accuracy of     8 : 65 %
# Accuracy of     9 : 55 %
